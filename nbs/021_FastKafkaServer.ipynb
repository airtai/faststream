# %%
# | default_exp _server

# %%
# | export

import asyncio
import multiprocessing
import platform
import signal
import threading
from contextlib import contextmanager
from typing import *
from types import FrameType

import asyncer
import typer

from fastkafka._components.helpers import _import_from_string
from fastkafka._components.logger import get_logger
from fastkafka._components._subprocess import terminate_asyncio_process
# Out:
# /home/kumaran/.local/lib/python3.11/site-packages/pydantic/_internal/_config.py:257: UserWarning: Valid config keys have changed in V2:
# * 'json_encoders' has been removed
#   warnings.warn(message, UserWarning)

# %%
import os
from time import sleep

from pydantic import BaseModel

from fastkafka._components.logger import suppress_timestamps
from fastkafka._components.test_dependencies import generate_app_in_tmp
from fastkafka.testing import ApacheKafkaBroker

# %%
# | notest

# allows async calls in notebooks

import nest_asyncio

# %%
# | notest

nest_asyncio.apply()

# %%
# | export

logger = get_logger(__name__, level=20)

# %%
suppress_timestamps()
logger = get_logger(__name__, level=20)
logger.info("ok")
# Out:
# [INFO] __main__: ok

# %%
# | export


class ServerProcess:
    def __init__(self, app: str, kafka_broker_name: str):
        """
        Represents a server process for running the FastKafka application.

        Args:
            app (str): Input in the form of 'path:app', where **path** is the path to a python file and **app** is an object of type **FastKafka**.
            kafka_broker_name (str): The name of the Kafka broker, one of the keys of the kafka_brokers dictionary passed in the constructor of FastKafka class.
        """
        self.app = app
        self.should_exit = False
        self.kafka_broker_name = kafka_broker_name

    def run(self) -> None:
        """
        Runs the FastKafka application server process.
        """
        return asyncio.run(self._serve())

    async def _serve(self) -> None:
        """
        Internal method that runs the FastKafka application server.
        """
        self._install_signal_handlers()

        self.application = _import_from_string(self.app)
        self.application.set_kafka_broker(self.kafka_broker_name)

        async with self.application:
            await self._main_loop()

    def _install_signal_handlers(self) -> None:
        """
        Installs signal handlers for handling termination signals.
        """
        if threading.current_thread() is not threading.main_thread():
            raise RuntimeError()

        loop = asyncio.get_event_loop()

        HANDLED_SIGNALS = (
            signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
            signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
        )
        if platform.system() == "Windows":
            HANDLED_SIGNALS = (*HANDLED_SIGNALS, signal.SIGBREAK) # type: ignore

        def handle_windows_exit(signum: int, frame: Optional[FrameType]) -> None:
            self.should_exit = True

        def handle_exit(sig: int) -> None:
            self.should_exit = True

        for sig in HANDLED_SIGNALS:
            if platform.system() == "Windows":
                signal.signal(sig, handle_windows_exit)
            else:
                loop.add_signal_handler(sig, handle_exit, sig)

    async def _main_loop(self) -> None:
        """
        Main loop for the FastKafka application server process.
        """
        while not self.should_exit:
            await asyncio.sleep(0.1)

# %%
# | export

_app = typer.Typer()


@_app.command()
def run_fastkafka_server_process(
    app: str = typer.Argument(
        ...,
        help="Input in the form of 'path:app', where **path** is the path to a python file and **app** is an object of type **FastKafka**.",
    ),
    kafka_broker: str = typer.Option(
        ...,
        help="Kafka broker, one of the keys of the kafka_brokers dictionary passed in the constructor of FastKafka class.",
    ),
) -> None:
    ServerProcess(app, kafka_broker).run()

# %%
# | notest

print("WARNING: make sure you save the notebook before running this cell\n")

print("Exporting and installing the new version of the CLI command...")
await asyncio.create_subprocess_exec("nbdev_export")
export_process = await asyncio.create_subprocess_exec("nbdev_export")
await export_process.wait()
assert export_process.returncode == 0

install_process = await asyncio.create_subprocess_exec(
    "pip", "install", "-e", "..[all]"
)
await install_process.wait()
assert install_process.returncode == 0

print("ok")
# Out:
# WARNING: make sure you save the notebook before running this cell
#
# Exporting and installing the new version of the CLI command...
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///work/fastkafka
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: aiokafka>=0.8.0 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.8.0rc0) (0.8.1)
# Requirement already satisfied: anyio>=3.0 in /usr/local/lib/python3.11/dist-packages (from fastkafka==0.8.0rc0) (3.7.0)
# Requirement already satisfied: asyncer>=0.0.2 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.8.0rc0) (0.0.2)
# Requirement already satisfied: docstring-parser>=0.15 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.8.0rc0) (0.15)
# Requirement already satisfied: nest-asyncio>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from fastkafka==0.8.0rc0) (1.5.6)
# Requirement already satisfied: pydantic>=2.0 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.8.0rc0) (2.0)
# Requirement already satisfied: tqdm>=4.62 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.8.0rc0) (4.65.0)
# Requirement already satisfied: typer>=0.7.0 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.8.0rc0) (0.9.0)
# Requirement already satisfied: async-timeout in /home/kumaran/.local/lib/python3.11/site-packages (from aiokafka>=0.8.0->fastkafka==0.8.0rc0) (4.0.2)
# Requirement already satisfied: kafka-python>=2.0.2 in /home/kumaran/.local/lib/python3.11/site-packages (from aiokafka>=0.8.0->fastkafka==0.8.0rc0) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from aiokafka>=0.8.0->fastkafka==0.8.0rc0) (23.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.0->fastkafka==0.8.0rc0) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.0->fastkafka==0.8.0rc0) (1.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/kumaran/.local/lib/python3.11/site-packages (from pydantic>=2.0->fastkafka==0.8.0rc0) (0.5.0)
# Requirement already satisfied: pydantic-core==2.0.1 in /home/kumaran/.local/lib/python3.11/site-packages (from pydantic>=2.0->fastkafka==0.8.0rc0) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/kumaran/.local/lib/python3.11/site-packages (from pydantic>=2.0->fastkafka==0.8.0rc0) (4.7.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/kumaran/.local/lib/python3.11/site-packages (from typer>=0.7.0->fastkafka==0.8.0rc0) (8.1.3)
# WARNING: fastkafka 0.8.0rc0 does not provide the extra 'all'
# Installing collected packages: fastkafka
#   Attempting uninstall: fastkafka
#     Found existing installation: fastkafka 0.8.0rc0
#     Uninstalling fastkafka-0.8.0rc0:
#       Successfully uninstalled fastkafka-0.8.0rc0
#   Running setup.py develop for fastkafka
# Successfully installed fastkafka-0.8.0rc0
# ok

# %%
listener_port = 9099
with generate_app_in_tmp() as app:
    async with ApacheKafkaBroker(listener_port=listener_port) as bootstrap_server:
        os.environ["KAFKA_HOSTNAME"], os.environ["KAFKA_PORT"] = bootstrap_server.split(
            ":"
        )
        proc = await asyncio.create_subprocess_exec(
            "run_fastkafka_server_process",
            "--kafka-broker",
            "localhost",
            app,
            stdout=asyncio.subprocess.PIPE,
        )
        sleep(5)
        await terminate_asyncio_process(proc)
        outputs, _ = await proc.communicate()

        print(outputs.decode("utf-8"))
        expected_returncode = 15 if platform.system() == "Windows" else 0
        assert proc.returncode == expected_returncode, f"{proc.returncode=}"
# Out:
# [INFO] fastkafka._components.test_dependencies: Java is already installed.
# [INFO] fastkafka._components.test_dependencies: But not exported to PATH, exporting...
# [INFO] fastkafka._components.test_dependencies: Kafka is installed.
# [INFO] fastkafka._components.test_dependencies: But not exported to PATH, exporting...
# [INFO] fastkafka._testing.apache_kafka_broker: Starting zookeeper...
# [INFO] fastkafka._testing.apache_kafka_broker: Starting kafka...
# [INFO] fastkafka._testing.apache_kafka_broker: Local Kafka broker up and running on 127.0.0.1:9099
# /home/kumaran/.local/lib/python3.11/site-packages/pydantic/_internal/_config.py:257: UserWarning: Valid config keys have changed in V2:
# * 'json_encoders' has been removed
#   warnings.warn(message, UserWarning)
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 581730...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 581730 terminated.
# 23-07-04 09:28:48.518 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# 23-07-04 09:28:48.533 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# 23-07-04 09:28:48.537 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# 23-07-04 09:28:48.540 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# 23-07-04 09:28:48.543 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# 23-07-04 09:28:48.543 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'group_id': '127.0.0.1:9099_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100, 'bootstrap_servers': '127.0.0.1:9099'}
# 23-07-04 09:28:48.543 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# 23-07-04 09:28:48.543 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'group_id': '127.0.0.1:9099_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100, 'bootstrap_servers': '127.0.0.1:9099'}
# 23-07-04 09:28:48.547 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# 23-07-04 09:28:48.547 [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# 23-07-04 09:28:48.547 [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# 23-07-04 09:28:48.547 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# 23-07-04 09:28:48.550 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# 23-07-04 09:28:48.550 [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# 23-07-04 09:28:48.550 [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# 23-07-04 09:28:48.550 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# 23-07-04 09:28:48.556 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# 23-07-04 09:28:48.578 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# 23-07-04 09:28:48.578 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# 23-07-04 09:28:48.588 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# 23-07-04 09:28:48.684 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# 23-07-04 09:28:48.686 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# 23-07-04 09:28:48.691 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# 23-07-04 09:28:48.693 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# 23-07-04 09:28:48.789 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# 23-07-04 09:28:48.791 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# 23-07-04 09:28:48.796 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# 23-07-04 09:28:48.799 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# 23-07-04 09:28:48.893 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# 23-07-04 09:28:48.895 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# 23-07-04 09:28:48.902 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# 23-07-04 09:28:48.904 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# 23-07-04 09:28:49.000 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.001 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.001 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.004 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.007 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.007 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.007 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.007 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.106 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.106 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.106 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.110 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.110 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.110 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.210 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.210 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.210 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.212 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.212 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.213 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.313 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.313 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.313 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.313 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.314 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.314 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.416 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.416 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.416 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.416 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.417 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.417 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.519 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.519 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.519 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.519 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.520 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.520 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.622 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.622 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.622 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.623 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.623 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.623 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.726 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.726 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.726 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.726 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.726 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.727 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.829 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.829 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.829 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.829 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.829 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.830 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.932 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.932 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.932 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:49.932 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:49.932 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:49.933 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.035 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.035 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.035 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.035 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.035 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.036 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.137 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.137 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.138 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.138 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.138 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.138 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.241 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.241 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.241 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.241 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.241 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.242 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.344 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.344 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.344 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.344 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.345 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.345 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.447 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.447 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.447 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.447 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.448 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.448 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.550 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.550 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.550 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.550 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.550 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.551 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.652 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.652 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.652 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.653 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.653 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.653 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.756 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.756 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.756 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.756 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.756 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.756 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.858 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.858 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.858 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.858 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.859 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.859 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.961 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.961 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.961 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:50.962 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:50.962 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:50.962 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.064 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.064 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.064 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.064 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.065 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.065 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.167 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.167 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.168 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.168 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.168 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.168 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.270 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.270 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.270 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.270 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.271 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.271 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.373 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.373 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.373 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.373 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.374 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.374 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.476 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.476 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.476 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.476 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.476 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.476 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.579 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.580 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.580 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.580 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.580 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.580 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.683 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.683 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.683 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.683 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.683 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.683 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.785 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.786 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.786 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.786 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.786 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.786 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.889 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.889 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.889 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.889 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.889 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.889 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.993 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.993 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.993 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:51.993 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:51.994 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:51.994 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.096 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.096 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.096 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.096 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.097 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.097 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.198 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.198 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.199 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.199 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.199 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.199 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.301 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.301 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.301 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.301 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.302 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.302 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.404 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.404 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.404 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.404 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.404 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.404 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.506 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.507 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.507 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.507 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.507 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.507 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.609 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.609 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.609 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.609 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.610 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.610 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.712 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.712 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.712 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.712 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.712 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.712 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.815 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.815 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.815 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.815 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.816 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.816 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.920 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.920 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.920 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:52.920 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:52.921 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:52.921 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:53.023 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:53.023 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:53.024 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:53.024 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:53.024 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:53.024 [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# 23-07-04 09:28:53.126 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:53.127 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:53.127 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# 23-07-04 09:28:53.127 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# 23-07-04 09:28:53.145 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:9099_group' (generation 1) with member_id aiokafka-0.8.1-06a216b2-5263-448b-baab-9c6942a6aa0f
# 23-07-04 09:28:53.147 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:9099_group' (generation 1) with member_id aiokafka-0.8.1-dd39baf5-c656-4fc7-8f71-5ab4975d466a
# 23-07-04 09:28:53.147 [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# 23-07-04 09:28:53.148 [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {} to {'training_data': 1, 'realitime_data': 1}.
# 23-07-04 09:28:53.182 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:9099_group with generation 1
# 23-07-04 09:28:53.182 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:9099_group
# 23-07-04 09:28:53.183 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:9099_group with generation 1
# 23-07-04 09:28:53.183 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group 127.0.0.1:9099_group
# 23-07-04 09:28:54.201 [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# 23-07-04 09:28:54.202 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# 23-07-04 09:28:54.202 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# 23-07-04 09:28:54.202 [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# 23-07-04 09:28:54.203 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# 23-07-04 09:28:54.203 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
#
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 581262...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 581262 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 580880...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 580880 terminated.

# %%
# | export


async def run_fastkafka_server(num_workers: int, app: str, kafka_broker: str) -> None:
    """
    Runs the FastKafka server with multiple worker processes.

    Args:
        num_workers (int): Number of FastKafka instances to run.
        app (str): Input in the form of 'path:app', where **path** is the path to a python file and **app** is an object of type **FastKafka**.
        kafka_broker (str): Kafka broker, one of the keys of the kafka_brokers dictionary passed in the constructor of FastKafka class.
    """
    loop = asyncio.get_event_loop()

    HANDLED_SIGNALS = (
        signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
        signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
    )
    if platform.system() == "Windows":
            HANDLED_SIGNALS = (*HANDLED_SIGNALS, signal.SIGBREAK) # type: ignore

    d = {"should_exit": False}

    def handle_windows_exit(
        signum: int, frame: Optional[FrameType], d: Dict[str, bool] = d
    ) -> None:
        d["should_exit"] = True

    def handle_exit(sig: int, d: Dict[str, bool] = d) -> None:
        d["should_exit"] = True

    for sig in HANDLED_SIGNALS:
        if platform.system() == "Windows":
            signal.signal(sig, handle_windows_exit)
        else:
            loop.add_signal_handler(sig, handle_exit, sig)

    async with asyncer.create_task_group() as tg:
        args = [
            "run_fastkafka_server_process",
            "--kafka-broker",
            kafka_broker,
            app,
        ]
        tasks = [
            tg.soonify(asyncio.create_subprocess_exec)(
                *args,
                stdout=asyncio.subprocess.PIPE,
                stdin=asyncio.subprocess.PIPE,
            )
            for i in range(num_workers)
        ]

    procs = [task.value for task in tasks]

    async def log_output(
        output: Optional[asyncio.StreamReader], pid: int, d: Dict[str, bool] = d
    ) -> None:
        if output is None:
            raise RuntimeError("Expected StreamReader, got None. Is stdout piped?")
        while not output.at_eof():
            outs = await output.readline()
            if outs != b"":
                typer.echo(f"[{pid:03d}]: " + outs.decode("utf-8"), nl=False)

    async with asyncer.create_task_group() as tg:
        for proc in procs:
            tg.soonify(log_output)(proc.stdout, proc.pid)

        while not d["should_exit"]:
            await asyncio.sleep(0.2)

        typer.echo("Starting process cleanup, this may take a few seconds...")
        for proc in procs:
            tg.soonify(terminate_asyncio_process)(proc)

    for proc in procs:
        output, _ = await proc.communicate()
        if output:
            typer.echo(f"[{proc.pid:03d}]: " + output.decode("utf-8"), nl=False)

    returncodes = [proc.returncode for proc in procs]
    if not returncodes == [0] * len(procs):
        typer.secho(
            f"Return codes are not all zero: {returncodes}",
            err=True,
            fg=typer.colors.RED,
        )
        raise typer.Exit(1)

# %%
# | export


@contextmanager
def run_in_process(
    target: Callable[..., Any]
) -> Generator[multiprocessing.Process, None, None]:
    """
    Runs the target function in a separate process.

    Args:
        target (Callable[..., Any]): The function to run in a separate process.

    Yields:
        Generator[multiprocessing.Process, None, None]: A generator that yields the process object.
    """
    p = multiprocessing.Process(target=target)
    try:
        p.start()
        yield p
    except Exception as e:
        print(f"Exception raised {e=}")
    finally:
        p.terminate()
        p.join()

# %%
# | notest

listener_port = 10000
async with ApacheKafkaBroker(listener_port=listener_port) as bootstrap_server:
    os.environ["KAFKA_HOSTNAME"], os.environ["KAFKA_PORT"] = bootstrap_server.split(":")

    with generate_app_in_tmp() as app:

        def run_fastkafka_server_test():
            asyncio.run(run_fastkafka_server(4, app, "localhost"))

        with run_in_process(run_fastkafka_server_test) as p:
            sleep(15)

        assert p.exitcode == 0, p.exitcode
        p.close()

print("ok")
# Out:
# [INFO] fastkafka._components.test_dependencies: Java is already installed.
# [INFO] fastkafka._components.test_dependencies: Kafka is installed.
# [INFO] fastkafka._testing.apache_kafka_broker: Starting zookeeper...
# [INFO] fastkafka._testing.apache_kafka_broker: Starting kafka...
# [INFO] fastkafka._testing.apache_kafka_broker: Local Kafka broker up and running on 127.0.0.1:10000
# [582619]: 23-07-04 09:29:00.433 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582621]: 23-07-04 09:29:00.435 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582617]: 23-07-04 09:29:00.437 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582615]: 23-07-04 09:29:00.438 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582615]: 23-07-04 09:29:00.456 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582621]: 23-07-04 09:29:00.456 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582619]: 23-07-04 09:29:00.457 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582617]: 23-07-04 09:29:00.457 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582617]: 23-07-04 09:29:00.462 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582619]: 23-07-04 09:29:00.462 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582615]: 23-07-04 09:29:00.462 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582621]: 23-07-04 09:29:00.462 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582619]: 23-07-04 09:29:00.467 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582621]: 23-07-04 09:29:00.467 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582615]: 23-07-04 09:29:00.467 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582617]: 23-07-04 09:29:00.467 [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [582615]: 23-07-04 09:29:00.472 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [582617]: 23-07-04 09:29:00.472 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [582615]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100, 'bootstrap_servers': '127.0.0.1:10000'}
# [582617]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100, 'bootstrap_servers': '127.0.0.1:10000'}
# [582621]: 23-07-04 09:29:00.472 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [582621]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100, 'bootstrap_servers': '127.0.0.1:10000'}
# [582621]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [582621]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100, 'bootstrap_servers': '127.0.0.1:10000'}
# [582619]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [582619]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100, 'bootstrap_servers': '127.0.0.1:10000'}
# [582619]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [582619]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100, 'bootstrap_servers': '127.0.0.1:10000'}
# [582619]: 23-07-04 09:29:00.479 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [582617]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [582617]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100, 'bootstrap_servers': '127.0.0.1:10000'}
# [582617]: 23-07-04 09:29:00.479 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# /home/kumaran/.local/lib/python3.11/site-packages/pydantic/_internal/_config.py:257: UserWarning: Valid config keys have changed in V2:
# * 'json_encoders' has been removed
#   warnings.warn(message, UserWarning)
# /home/kumaran/.local/lib/python3.11/site-packages/pydantic/_internal/_config.py:257: UserWarning: Valid config keys have changed in V2:
# * 'json_encoders' has been removed
#   warnings.warn(message, UserWarning)
# /home/kumaran/.local/lib/python3.11/site-packages/pydantic/_internal/_config.py:257: UserWarning: Valid config keys have changed in V2:
# * 'json_encoders' has been removed
#   warnings.warn(message, UserWarning)
# /home/kumaran/.local/lib/python3.11/site-packages/pydantic/_internal/_config.py:257: UserWarning: Valid config keys have changed in V2:
# * 'json_encoders' has been removed
#   warnings.warn(message, UserWarning)
# [582615]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [582615]: 23-07-04 09:29:00.473 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100, 'bootstrap_servers': '127.0.0.1:10000'}
# [582615]: 23-07-04 09:29:00.478 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [582615]: 23-07-04 09:29:00.478 [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [582615]: 23-07-04 09:29:00.479 [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [582615]: 23-07-04 09:29:00.479 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [582619]: 23-07-04 09:29:00.479 [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [582619]: 23-07-04 09:29:00.479 [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [582619]: 23-07-04 09:29:00.479 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [582619]: 23-07-04 09:29:00.484 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [582619]: 23-07-04 09:29:00.484 [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [582619]: 23-07-04 09:29:00.484 [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [582619]: 23-07-04 09:29:00.484 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [582619]: 23-07-04 09:29:00.495 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582617]: 23-07-04 09:29:00.479 [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [582617]: 23-07-04 09:29:00.479 [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [582617]: 23-07-04 09:29:00.479 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [582617]: 23-07-04 09:29:00.484 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [582617]: 23-07-04 09:29:00.484 [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [582617]: 23-07-04 09:29:00.484 [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [582617]: 23-07-04 09:29:00.484 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [582617]: 23-07-04 09:29:00.495 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582617]: 23-07-04 09:29:00.495 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582621]: 23-07-04 09:29:00.479 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [582621]: 23-07-04 09:29:00.479 [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [582621]: 23-07-04 09:29:00.480 [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [582621]: 23-07-04 09:29:00.480 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [582621]: 23-07-04 09:29:00.485 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [582621]: 23-07-04 09:29:00.485 [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [582621]: 23-07-04 09:29:00.485 [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [582621]: 23-07-04 09:29:00.485 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [582621]: 23-07-04 09:29:00.495 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582621]: 23-07-04 09:29:00.495 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582615]: 23-07-04 09:29:00.483 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [582615]: 23-07-04 09:29:00.483 [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [582615]: 23-07-04 09:29:00.483 [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [582615]: 23-07-04 09:29:00.483 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [582615]: 23-07-04 09:29:00.495 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582615]: 23-07-04 09:29:00.495 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.500 [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [582621]: 23-07-04 09:29:00.500 [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [582621]: 23-07-04 09:29:00.503 [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [582615]: 23-07-04 09:29:00.500 [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [582615]: 23-07-04 09:29:00.503 [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [582619]: 23-07-04 09:29:00.531 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582617]: 23-07-04 09:29:00.531 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582617]: 23-07-04 09:29:00.531 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582619]: 23-07-04 09:29:00.534 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582619]: 23-07-04 09:29:00.604 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582621]: 23-07-04 09:29:00.604 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582621]: 23-07-04 09:29:00.605 [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [582615]: 23-07-04 09:29:00.605 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582615]: 23-07-04 09:29:00.605 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582615]: 23-07-04 09:29:00.606 [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [582615]: 23-07-04 09:29:00.607 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582621]: 23-07-04 09:29:00.606 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.606 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582621]: 23-07-04 09:29:00.611 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582617]: 23-07-04 09:29:00.634 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.636 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582617]: 23-07-04 09:29:00.636 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582617]: 23-07-04 09:29:00.637 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582617]: 23-07-04 09:29:00.640 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582619]: 23-07-04 09:29:00.639 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582615]: 23-07-04 09:29:00.707 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.708 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582615]: 23-07-04 09:29:00.708 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.709 [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [582621]: 23-07-04 09:29:00.709 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582615]: 23-07-04 09:29:00.710 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582615]: 23-07-04 09:29:00.711 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582621]: 23-07-04 09:29:00.712 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582621]: 23-07-04 09:29:00.716 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582621]: 23-07-04 09:29:00.719 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582617]: 23-07-04 09:29:00.740 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.742 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582617]: 23-07-04 09:29:00.744 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582617]: 23-07-04 09:29:00.745 [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [582619]: 23-07-04 09:29:00.745 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582617]: 23-07-04 09:29:00.747 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582619]: 23-07-04 09:29:00.813 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582615]: 23-07-04 09:29:00.813 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582615]: 23-07-04 09:29:00.814 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582621]: 23-07-04 09:29:00.814 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582615]: 23-07-04 09:29:00.815 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582619]: 23-07-04 09:29:00.815 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582621]: 23-07-04 09:29:00.815 [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [582615]: 23-07-04 09:29:00.817 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582621]: 23-07-04 09:29:00.821 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582621]: 23-07-04 09:29:00.823 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582617]: 23-07-04 09:29:00.847 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.848 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.849 [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [582617]: 23-07-04 09:29:00.849 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582617]: 23-07-04 09:29:00.849 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582617]: 23-07-04 09:29:00.851 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582621]: 23-07-04 09:29:00.917 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.917 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.918 [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [582615]: 23-07-04 09:29:00.917 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582621]: 23-07-04 09:29:00.918 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582615]: 23-07-04 09:29:00.919 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582615]: 23-07-04 09:29:00.919 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582615]: 23-07-04 09:29:00.921 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582621]: 23-07-04 09:29:00.927 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582621]: 23-07-04 09:29:00.929 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582619]: 23-07-04 09:29:00.951 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582617]: 23-07-04 09:29:00.952 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582619]: 23-07-04 09:29:00.953 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582617]: 23-07-04 09:29:00.954 [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [582617]: 23-07-04 09:29:00.954 [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [582617]: 23-07-04 09:29:00.957 [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [582619]: 23-07-04 09:29:01.024 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [582619]: 23-07-04 09:29:01.024 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:01.024 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:01.024 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:01.024 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:01.025 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:01.025 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:01.025 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:01.024 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:01.024 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:01.024 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582619]: 23-07-04 09:29:01.024 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:01.033 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:01.033 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:01.033 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582619]: 23-07-04 09:29:01.048 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.1-6dda35a7-c9f1-4a03-8cbc-d5abeadbd735
# [582621]: 23-07-04 09:29:01.048 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.1-072b36e3-8270-48f0-824d-ea03acdfb1d3
# [582621]: 23-07-04 09:29:01.048 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.1-b035bbc3-514f-4896-9fb8-eb3e2b3e61cb
# [582615]: 23-07-04 09:29:01.050 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.1-eeac3f9f-23c2-4a09-ae92-0942671b81de
# [582615]: 23-07-04 09:29:01.050 [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [582615]: 23-07-04 09:29:01.050 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.1-a1c6c3c0-2cea-438f-915c-4f60c3887959
# [582615]: 23-07-04 09:29:01.052 [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {} to {'training_data': 1, 'realitime_data': 1}.
# [582619]: 23-07-04 09:29:01.056 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [582619]: 23-07-04 09:29:01.056 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [582619]: 23-07-04 09:29:01.056 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582617]: 23-07-04 09:29:01.057 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [582617]: 23-07-04 09:29:01.057 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [582617]: 23-07-04 09:29:01.057 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582617]: 23-07-04 09:29:01.061 [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [582617]: 23-07-04 09:29:01.061 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [582617]: 23-07-04 09:29:01.061 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582619]: 23-07-04 09:29:01.091 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [582619]: 23-07-04 09:29:01.091 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:01.091 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [582621]: 23-07-04 09:29:01.092 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:01.092 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [582621]: 23-07-04 09:29:01.092 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:01.092 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [582615]: 23-07-04 09:29:01.092 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:01.093 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [582615]: 23-07-04 09:29:01.093 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:04.096 [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [582621]: 23-07-04 09:29:04.097 [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [582619]: 23-07-04 09:29:04.097 [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [582615]: 23-07-04 09:29:04.097 [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [582615]: 23-07-04 09:29:04.097 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset() for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:04.097 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:04.097 [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [582621]: 23-07-04 09:29:04.097 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset() for group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:04.097 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset() for group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:04.097 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:04.097 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582619]: 23-07-04 09:29:04.110 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='realitime_data', partition=0)}) for group 127.0.0.1:10000_group
# [582619]: 23-07-04 09:29:04.110 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:04.110 [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='training_data', partition=0)}) for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:04.110 [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [582619]: 23-07-04 09:29:04.111 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.1-b7e6ed3a-37d7-4561-82bd-0aa70ff0eeef
# [582619]: 23-07-04 09:29:04.112 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.1-6dda35a7-c9f1-4a03-8cbc-d5abeadbd735
# [582621]: 23-07-04 09:29:04.112 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.1-072b36e3-8270-48f0-824d-ea03acdfb1d3
# [582621]: 23-07-04 09:29:04.113 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.1-b035bbc3-514f-4896-9fb8-eb3e2b3e61cb
# [582617]: 23-07-04 09:29:04.114 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.1-dda97c6f-143e-479f-bc77-4b3781796305
# [582617]: 23-07-04 09:29:04.115 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.1-5cc40b91-fb51-4821-b596-c7932cf10d0c
# [582615]: 23-07-04 09:29:04.115 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.1-eeac3f9f-23c2-4a09-ae92-0942671b81de
# [582615]: 23-07-04 09:29:04.115 [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [582615]: 23-07-04 09:29:04.115 [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.1-a1c6c3c0-2cea-438f-915c-4f60c3887959
# [582619]: 23-07-04 09:29:04.117 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [582619]: 23-07-04 09:29:04.117 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [582619]: 23-07-04 09:29:04.117 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [582619]: 23-07-04 09:29:04.117 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:04.117 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [582621]: 23-07-04 09:29:04.117 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [582621]: 23-07-04 09:29:04.118 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [582621]: 23-07-04 09:29:04.118 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [582617]: 23-07-04 09:29:04.118 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [582617]: 23-07-04 09:29:04.118 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [582617]: 23-07-04 09:29:04.118 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [582617]: 23-07-04 09:29:04.119 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:04.119 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [582615]: 23-07-04 09:29:04.119 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [582615]: 23-07-04 09:29:04.119 [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [582615]: 23-07-04 09:29:04.119 [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:10000_group
# Starting process cleanup, this may take a few seconds...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 582615...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 582617...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 582619...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 582621...
# [582619]: 23-07-04 09:29:16.018 [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [582619]: 23-07-04 09:29:16.018 [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [582619]: 23-07-04 09:29:16.018 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [582619]: 23-07-04 09:29:16.018 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [582619]: 23-07-04 09:29:16.019 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [582619]: 23-07-04 09:29:16.019 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [582617]: 23-07-04 09:29:16.019 [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [582617]: 23-07-04 09:29:16.019 [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [582617]: 23-07-04 09:29:16.020 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [582617]: 23-07-04 09:29:16.020 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [582617]: 23-07-04 09:29:16.020 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [582617]: 23-07-04 09:29:16.020 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [582621]: 23-07-04 09:29:16.022 [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [582621]: 23-07-04 09:29:16.022 [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [582621]: 23-07-04 09:29:16.022 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [582621]: 23-07-04 09:29:16.022 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [582621]: 23-07-04 09:29:16.022 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [582621]: 23-07-04 09:29:16.022 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [582615]: 23-07-04 09:29:16.032 [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [582615]: 23-07-04 09:29:16.032 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [582615]: 23-07-04 09:29:16.033 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [582615]: 23-07-04 09:29:16.037 [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [582615]: 23-07-04 09:29:16.038 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [582615]: 23-07-04 09:29:16.038 [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 582617 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 582621 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 582619 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 582615 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 582147...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 582147 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 581766...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 581766 terminated.
# ok
