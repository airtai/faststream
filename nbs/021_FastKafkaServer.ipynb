# %%
# | default_exp _server

# %%
# | export

import asyncio
import multiprocessing
import signal
import threading
from contextlib import contextmanager
from typing import *

import asyncer
import typer

from fastkafka._components.helpers import _import_from_string
from fastkafka._components.logger import get_logger

# %%
import os
from time import sleep

from pydantic import BaseModel

from fastkafka._components.logger import supress_timestamps
from fastkafka._components.test_dependencies import generate_app_in_tmp
from fastkafka.testing import LocalKafkaBroker

# %%
# | notest

# allows async calls in notebooks

import nest_asyncio

# %%
# | notest

nest_asyncio.apply()

# %%
# | export

logger = get_logger(__name__)

# %%
supress_timestamps()
logger = get_logger(__name__, level=20)
logger.info("ok")
# Out:
# [INFO] __main__: ok

# %%
# | export


class ServerProcess:
    def __init__(self, app: str, kafka_broker: Optional[str] = None):
        self.app = app
        self.should_exit = False
        self.kafka_broker = kafka_broker

    def run(self) -> None:
        return asyncio.run(self._serve())

    async def _serve(self) -> None:
        self._install_signal_handlers()

        self.application = _import_from_string(self.app)
        if self.kafka_broker is not None:
            self.application.set_kafka_broker(self.kafka_broker)

        async with self.application:
            await self._main_loop()

    def _install_signal_handlers(self) -> None:
        if threading.current_thread() is not threading.main_thread():
            raise RuntimeError()

        loop = asyncio.get_event_loop()

        HANDLED_SIGNALS = (
            signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
            signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
        )

        def handle_exit(sig: int) -> None:
            self.should_exit = True

        for sig in HANDLED_SIGNALS:
            loop.add_signal_handler(sig, handle_exit, sig)

    async def _main_loop(self) -> None:
        while not self.should_exit:
            await asyncio.sleep(0.1)

# %%
# | export

_app = typer.Typer()


@_app.command()
def run_fastkafka_server_process(
    app: str = typer.Argument(
        ...,
        help="input in the form of 'path:app', where **path** is the path to a python file and **app** is an object of type **FastKafka**.",
    ),
    kafka_broker: Optional[str] = typer.Option(
        None, help="broker to use from kafka_brokers"
    ),
) -> None:
    ServerProcess(app, kafka_broker).run()

# %%
# | notest

print("WARNING: make sure you save the notebook before running this cell\n")

print("Exporting and installing the new version of the CLI command...")
await asyncio.create_subprocess_exec("nbdev_export")
export_process = await asyncio.create_subprocess_exec("nbdev_export")
await export_process.wait()
assert export_process.returncode == 0

install_process = await asyncio.create_subprocess_exec(
    "pip", "install", "-e", "..[all]"
)
await install_process.wait()
assert install_process.returncode == 0

print("ok")
# Out:
# WARNING: make sure you save the notebook before running this cell
#
# Exporting and installing the new version of the CLI command...
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///work/fastkafka
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: aiokafka>=0.8.0 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.3.0rc0) (0.8.0)
# Requirement already satisfied: anyio>=3.0 in /usr/local/lib/python3.11/dist-packages (from fastkafka==0.3.0rc0) (3.6.2)
# Requirement already satisfied: asyncer>=0.0.2 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.3.0rc0) (0.0.2)
# Requirement already satisfied: docstring-parser>=0.15 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.3.0rc0) (0.15)
# Requirement already satisfied: fastcore>=1.5.27 in /usr/local/lib/python3.11/dist-packages (from fastkafka==0.3.0rc0) (1.5.28)
# Requirement already satisfied: pydantic>=1.9 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.3.0rc0) (1.10.6)
# Requirement already satisfied: tqdm>=4.62 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.3.0rc0) (4.65.0)
# Requirement already satisfied: typer>=0.7.0 in /home/kumaran/.local/lib/python3.11/site-packages (from fastkafka==0.3.0rc0) (0.7.0)
# Requirement already satisfied: async-timeout in /home/kumaran/.local/lib/python3.11/site-packages (from aiokafka>=0.8.0->fastkafka==0.3.0rc0) (4.0.2)
# Requirement already satisfied: kafka-python>=2.0.2 in /home/kumaran/.local/lib/python3.11/site-packages (from aiokafka>=0.8.0->fastkafka==0.3.0rc0) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from aiokafka>=0.8.0->fastkafka==0.3.0rc0) (23.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.0->fastkafka==0.3.0rc0) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.0->fastkafka==0.3.0rc0) (1.3.0)
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (from fastcore>=1.5.27->fastkafka==0.3.0rc0) (23.0.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/kumaran/.local/lib/python3.11/site-packages (from pydantic>=1.9->fastkafka==0.3.0rc0) (4.5.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/kumaran/.local/lib/python3.11/site-packages (from typer>=0.7.0->fastkafka==0.3.0rc0) (8.1.3)
# WARNING: fastkafka 0.3.0rc0 does not provide the extra 'all'
# Installing collected packages: fastkafka
#   Attempting uninstall: fastkafka
#     Found existing installation: fastkafka 0.3.0rc0
#     Uninstalling fastkafka-0.3.0rc0:
#       Successfully uninstalled fastkafka-0.3.0rc0
#   Running setup.py develop for fastkafka
# Successfully installed fastkafka-0.3.0rc0
# ok

# %%
# | export


async def terminate_asyncio_process(p: asyncio.subprocess.Process) -> None:
    logger.info(f"terminate_asyncio_process(): Terminating the process {p.pid}...")
    # Check if SIGINT already propagated to process
    try:
        await asyncio.wait_for(p.wait(), 1)
        logger.info(
            f"terminate_asyncio_process(): Process {p.pid} was already terminated."
        )
        return
    except asyncio.TimeoutError:
        pass

    for i in range(3):
        p.terminate()
        try:
            await asyncio.wait_for(p.wait(), 10)
            logger.info(f"terminate_asyncio_process(): Process {p.pid} terminated.")
            return
        except asyncio.TimeoutError:
            logger.warning(
                f"terminate_asyncio_process(): Process {p.pid} not terminated, retrying..."
            )

    logger.warning(f"Killing the process {p.pid}...")
    p.kill()
    await p.wait()
    logger.warning(f"terminate_asyncio_process(): Process {p.pid} killed!")

# %%
listener_port = 9099
with generate_app_in_tmp() as app:
    async with LocalKafkaBroker(listener_port=listener_port) as bootstrap_server:
        os.environ["KAFKA_HOSTNAME"], os.environ["KAFKA_PORT"] = bootstrap_server.split(":")
        proc = await asyncio.create_subprocess_exec(
            "run_fastkafka_server_process",
            "--kafka-broker",
            "localhost",
            app,
            stdout=asyncio.subprocess.PIPE,
        )
        sleep(5)
        await terminate_asyncio_process(proc)
        outputs, _ = await proc.communicate()

        print(outputs.decode("utf-8"))
        assert proc.returncode == 0
# Out:
# [INFO] fastkafka._components.test_dependencies: Java is already installed.
# [INFO] fastkafka._components.test_dependencies: But not exported to PATH, exporting...
# [INFO] fastkafka._components.test_dependencies: Kafka is installed.
# [INFO] fastkafka._components.test_dependencies: But not exported to PATH, exporting...
# [INFO] fastkafka._testing.local_broker: Starting zookeeper...
# [INFO] fastkafka._testing.local_broker: Starting kafka...
# [INFO] fastkafka._testing.local_broker: Local Kafka broker up and running on 127.0.0.1:9099
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 596101...
# [INFO] __main__: terminate_asyncio_process(): Process 596101 terminated.
# [INFO] fastkafka._application.app: set_kafka_broker() : Setting bootstrap_servers value to '127.0.0.1:9099'
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:9099', 'group_id': '127.0.0.1:9099_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:9099', 'group_id': '127.0.0.1:9099_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:9099_group' (generation 1) with member_id aiokafka-0.8.0-3b12e378-e031-4de1-a4c4-455332149584
# [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:9099_group' (generation 1) with member_id aiokafka-0.8.0-3822f3b0-08ea-4665-8e21-6f97623c04cd
# [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {} to {'training_data': 1, 'realitime_data': 1}.
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:9099_group with generation 1
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:9099_group with generation 1
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
#
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 595639...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 595639 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 595266...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 595266 terminated.

# %%
listener_port = 9099
with generate_app_in_tmp() as app:
    async with LocalKafkaBroker(listener_port=listener_port) as bootstrap_server:
        os.environ["KAFKA_HOSTNAME"], os.environ["KAFKA_PORT"] = bootstrap_server.split(":")
        proc = await asyncio.create_subprocess_exec(
            "run_fastkafka_server_process", app, stdout=asyncio.subprocess.PIPE
        )
        sleep(5)
        await terminate_asyncio_process(proc)
        outputs, _ = await proc.communicate()

        print(outputs.decode("utf-8"))
        assert proc.returncode == 0
# Out:
# [INFO] fastkafka._components.test_dependencies: Java is already installed.
# [INFO] fastkafka._components.test_dependencies: Kafka is installed.
# [INFO] fastkafka._testing.local_broker: Starting zookeeper...
# [INFO] fastkafka._testing.local_broker: Starting kafka...
# [INFO] fastkafka._testing.local_broker: Local Kafka broker up and running on 127.0.0.1:9099
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 596961...
# [INFO] __main__: terminate_asyncio_process(): Process 596961 terminated.
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:9099', 'group_id': '127.0.0.1:9099_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:9099', 'group_id': '127.0.0.1:9099_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [WARNING] aiokafka.consumer.group_coordinator: Marking the coordinator dead (node 0)for group 127.0.0.1:9099_group.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:9099_group' (generation 1) with member_id aiokafka-0.8.0-53655f2d-4d37-4ce4-b830-4607e71b7e5b
# [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:9099_group' (generation 1) with member_id aiokafka-0.8.0-6bba88f0-fc16-4088-af6e-c9eec235682c
# [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {} to {'realitime_data': 1, 'training_data': 1}.
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:9099_group with generation 1
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:9099_group with generation 1
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
#
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 596500...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 596500 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 596129...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 596129 terminated.

# %%
# | export


async def run_fastkafka_server(
    num_workers: int, app: str, kafka_broker: Optional[str] = None
) -> None:
    loop = asyncio.get_event_loop()

    HANDLED_SIGNALS = (
        signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
        signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
    )

    d = {"should_exit": False}

    def handle_exit(sig: int, d: Dict[str, bool] = d) -> None:
        d["should_exit"] = True

    for sig in HANDLED_SIGNALS:
        loop.add_signal_handler(sig, handle_exit, sig)

    async with asyncer.create_task_group() as tg:
        args = [
            "run_fastkafka_server_process",
            app,
        ]
        if kafka_broker is not None:
            args[1:1] = ["--kafka-broker", kafka_broker]
        tasks = [
            tg.soonify(asyncio.create_subprocess_exec)(
                *args,
                stdout=asyncio.subprocess.PIPE,
                stdin=asyncio.subprocess.PIPE,
            )
            for i in range(num_workers)
        ]

    procs = [task.value for task in tasks]

    async def log_output(
        output: Optional[asyncio.StreamReader], pid: int, d: Dict[str, bool] = d
    ) -> None:
        if output is None:
            raise RuntimeError("Expected StreamReader, got None. Is stdout piped?")
        while not output.at_eof():
            outs = await output.readline()
            if outs != b"":
                typer.echo(f"[{pid:03d}]: " + outs.decode("utf-8"), nl=False)

    async with asyncer.create_task_group() as tg:
        for proc in procs:
            tg.soonify(log_output)(proc.stdout, proc.pid)

        while not d["should_exit"]:
            await asyncio.sleep(0.2)

        typer.echo("Starting process cleanup, this may take a few seconds...")
        for proc in procs:
            tg.soonify(terminate_asyncio_process)(proc)

    for proc in procs:
        output, _ = await proc.communicate()
        if output:
            typer.echo(f"[{proc.pid:03d}]: " + output.decode("utf-8"), nl=False)

    returncodes = [proc.returncode for proc in procs]
    if not returncodes == [0] * len(procs):
        typer.secho(
            f"Return codes are not all zero: {returncodes}",
            err=True,
            fg=typer.colors.RED,
        )
        raise typer.Exit(1)

# %%
# | export


@contextmanager
def run_in_process(
    target: Callable[..., Any]
) -> Generator[multiprocessing.Process, None, None]:
    p = multiprocessing.Process(target=target)
    try:
        p.start()
        yield p
    except Exception as e:
        print(f"Exception raised {e=}")
    finally:
        p.terminate()
        p.join()

# %%
# | notest

listener_port = 10000
async with LocalKafkaBroker(listener_port=listener_port) as bootstrap_server:
    os.environ["KAFKA_HOSTNAME"], os.environ["KAFKA_PORT"] = bootstrap_server.split(":")

    with generate_app_in_tmp() as app:

        def run_fastkafka_server_test():
            asyncio.run(run_fastkafka_server(4, app, "localhost"))

        with run_in_process(run_fastkafka_server_test) as p:
            sleep(15)

        assert p.exitcode == 0, p.exitcode
        p.close()

print("ok")
# Out:
# [INFO] fastkafka._components.test_dependencies: Java is already installed.
# [INFO] fastkafka._components.test_dependencies: Kafka is installed.
# [INFO] fastkafka._testing.local_broker: Starting zookeeper...
# [INFO] fastkafka._testing.local_broker: Starting kafka...
# [INFO] fastkafka._testing.local_broker: Local Kafka broker up and running on 127.0.0.1:10000
# [597823]: [INFO] fastkafka._application.app: set_kafka_broker() : Setting bootstrap_servers value to '127.0.0.1:10000'
# [597825]: [INFO] fastkafka._application.app: set_kafka_broker() : Setting bootstrap_servers value to '127.0.0.1:10000'
# [597829]: [INFO] fastkafka._application.app: set_kafka_broker() : Setting bootstrap_servers value to '127.0.0.1:10000'
# [597829]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597823]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597825]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597827]: [INFO] fastkafka._application.app: set_kafka_broker() : Setting bootstrap_servers value to '127.0.0.1:10000'
# [597827]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597823]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597829]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597827]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597825]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597825]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597823]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597827]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597829]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597825]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597827]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597829]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597823]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [597829]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [597829]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [597823]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [597823]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [597825]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [597825]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [597827]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [597827]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [597829]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [597829]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [597825]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [597825]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [597823]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [597823]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [597827]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [597827]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [597827]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597827]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597829]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [597823]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [597825]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597825]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597825]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [597825]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [597827]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [597829]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597829]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [597827]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597829]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597823]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597825]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597825]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [597827]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597827]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [597825]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597825]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [597823]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597829]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597827]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597829]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [597829]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597827]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597829]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597825]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [597827]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597827]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [597825]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597825]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [597823]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597825]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597829]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597829]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [597827]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597827]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597829]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597829]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597823]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597825]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597827]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [597825]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [597827]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [597823]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597825]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597825]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597829]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597827]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597829]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [597827]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597829]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597829]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597825]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [597825]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [597827]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597823]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597827]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [597825]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [597825]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [597823]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [597827]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-5e06f72b-af9b-4be2-ab18-47478f9d9317
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-43986448-74a3-412e-8213-fcddd6906dff
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-c11b39de-f07e-48da-943e-5211ed41300f
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {} to {'training_data': 1, 'realitime_data': 1}.
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group 127.0.0.1:10000_group
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [597823]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [597823]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [597823]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597825]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [597825]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [597825]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [597827]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597825]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [597825]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [597825]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597823]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [597823]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [597823]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597829]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [597829]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [597827]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset() for group 127.0.0.1:10000_group
# [597827]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='training_data', partition=0)}) for group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='realitime_data', partition=0)}) for group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [597825]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-5541de48-07e9-4115-a2c3-7eb9ea9b8f7d
# [597825]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-3c7098ff-32a8-4386-903d-aeb7fbbc4dfb
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-5e06f72b-af9b-4be2-ab18-47478f9d9317
# [597823]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-d51187f3-1ae9-4b8e-8376-1b720e66bcb6
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-43986448-74a3-412e-8213-fcddd6906dff
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-c11b39de-f07e-48da-943e-5211ed41300f
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-3722acd0-16e9-44f0-8eb7-4a3777d0b9a6
# [597823]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-a8469371-9cd8-4c2c-8997-606291d3ebcd
# [597825]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [597825]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:10000_group
# [597825]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [597825]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [597829]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [597823]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [597823]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [597823]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [597823]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [597827]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# Starting process cleanup, this may take a few seconds...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 597823...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 597825...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 597827...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 597829...
# [597823]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [597823]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [597823]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [597829]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [597829]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [597829]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] __main__: terminate_asyncio_process(): Process 597823 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 597829 terminated.
# [597827]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [597827]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [597827]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [597825]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [597825]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [597825]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] __main__: terminate_asyncio_process(): Process 597827 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 597825 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 597363...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 597363 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 596990...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 596990 terminated.
# ok

# %%
# | notest

listener_port = 10000
async with LocalKafkaBroker(listener_port=listener_port) as bootstrap_server:
    os.environ["KAFKA_HOSTNAME"], os.environ["KAFKA_PORT"] = bootstrap_server.split(":")

    with generate_app_in_tmp() as app:

        def run_fastkafka_server_test():
            asyncio.run(run_fastkafka_server(4, app, kafka_broker=None))

        with run_in_process(run_fastkafka_server_test) as p:
            sleep(15)

        assert p.exitcode == 0, p.exitcode
        p.close()

print("ok")
# Out:
# [INFO] fastkafka._components.test_dependencies: Java is already installed.
# [INFO] fastkafka._components.test_dependencies: Kafka is installed.
# [INFO] fastkafka._testing.local_broker: Starting zookeeper...
# [INFO] fastkafka._testing.local_broker: Starting kafka...
# [INFO] fastkafka._testing.local_broker: Local Kafka broker up and running on 127.0.0.1:10000
# [599189]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599187]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599185]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599191]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599187]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599191]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599189]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599185]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599185]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599189]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599187]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599191]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599187]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599189]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599185]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599191]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [599185]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [599185]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [599191]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [599191]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [599189]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [599189]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [599187]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [599187]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [599185]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [599185]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [599187]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [599187]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [599189]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [599189]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [599191]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [599191]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [599187]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599185]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599185]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599187]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [599191]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [599191]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [599185]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [599185]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [599187]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599189]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599187]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599185]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599187]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599187]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [599185]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [599185]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599191]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599185]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599189]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599187]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599187]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599187]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599185]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599187]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [599185]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [599185]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599191]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599185]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599189]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599189]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599187]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599187]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599185]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599187]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599187]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [599185]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599191]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599191]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599185]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599185]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599189]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599189]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599187]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599187]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599187]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599191]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [599191]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599185]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599187]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599185]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599185]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599185]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599189]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599189]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599189]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [599187]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [599187]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [599185]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [599187]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [599185]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599189]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [599189]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-2a3e0277-5ffc-4aa7-9647-84eec5c9fbf1
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [599189]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599189]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [599189]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [599189]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-8d1b0116-2983-4748-9842-ce3346e92b2f
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-4d9c8995-6728-402e-a116-7c394adaba15
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-f5427b2b-c4c6-403a-af9b-5d4e99599527
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-d33939f5-d549-441f-9b37-d21e2829c203
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {} to {'realitime_data': 1, 'training_data': 1}.
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [599187]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599185]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599185]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599187]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-2a3e0277-5ffc-4aa7-9647-84eec5c9fbf1
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-8d1b0116-2983-4748-9842-ce3346e92b2f
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-f5427b2b-c4c6-403a-af9b-5d4e99599527
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-4d9c8995-6728-402e-a116-7c394adaba15
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-df285a50-bd4d-46aa-8b2c-4f9e2cb31ff2
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-d33939f5-d549-441f-9b37-d21e2829c203
# [599189]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-827f2f61-823f-4554-923e-24037f580ff3
# [599189]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-6cc28779-f9b3-477d-aac0-ee5350e8acc8
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group 127.0.0.1:10000_group
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [599187]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [599185]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:10000_group
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [599191]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [599189]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [599189]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [599189]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [599189]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# Starting process cleanup, this may take a few seconds...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 599185...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 599187...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 599189...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 599191...
# [599189]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [599191]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [599189]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [599189]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [599191]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [599191]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [599185]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [599185]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [599185]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [599187]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [599187]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [599187]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] __main__: terminate_asyncio_process(): Process 599189 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 599191 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 599185 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 599187 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 598724...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 598724 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 598351...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 598351 terminated.
# ok
