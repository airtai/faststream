# %%
# | default_exp _server

# %%
# | export

import asyncio
import multiprocessing
import signal
import threading
from contextlib import contextmanager
from typing import *

import asyncer
import typer

from fastkafka._components.helpers import _import_from_string
from fastkafka._components.logger import get_logger

# %%
import os
from time import sleep

from pydantic import BaseModel

from fastkafka._components.logger import supress_timestamps
from fastkafka._components.test_dependencies import generate_app_in_tmp
from fastkafka.testing import LocalKafkaBroker

# %%
# | notest

# allows async calls in notebooks

import nest_asyncio

# %%
# | notest

nest_asyncio.apply()

# %%
# | export

logger = get_logger(__name__)

# %%
supress_timestamps()
logger = get_logger(__name__, level=20)
logger.info("ok")
# Out:
# [INFO] __main__: ok

# %%
# | export


class ServerProcess:
    def __init__(self, app: str):
        self.app = app
        self.should_exit = False

    def run(self) -> None:
        return asyncio.run(self._serve())

    async def _serve(self) -> None:
        self._install_signal_handlers()

        self.application = _import_from_string(self.app)

        async with self.application:
            await self._main_loop()

    def _install_signal_handlers(self) -> None:
        if threading.current_thread() is not threading.main_thread():
            raise RuntimeError()

        loop = asyncio.get_event_loop()

        HANDLED_SIGNALS = (
            signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
            signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
        )

        def handle_exit(sig: int) -> None:
            self.should_exit = True

        for sig in HANDLED_SIGNALS:
            loop.add_signal_handler(sig, handle_exit, sig)

    async def _main_loop(self) -> None:
        while not self.should_exit:
            await asyncio.sleep(0.1)

# %%
# | export

_app = typer.Typer()


@_app.command()
def run_fastkafka_server_process(
    app: str = typer.Argument(
        ...,
        help="input in the form of 'path:app', where **path** is the path to a python file and **app** is an object of type **FastKafka**.",
    )
) -> None:
    ServerProcess(app).run()

# %%
# | notest

print("WARNING: make sure you save the notebook before running this cell\n")

print("Exporting and installing the new version of the CLI command...")
await asyncio.create_subprocess_exec("nbdev_export")
export_process = await asyncio.create_subprocess_exec("nbdev_export")
await export_process.wait()
assert export_process.returncode == 0

install_process = await asyncio.create_subprocess_exec(
    "pip", "install", "-e", "..[all]"
)
await install_process.wait()
assert install_process.returncode == 0

print("ok")
# Out:
# WARNING: make sure you save the notebook before running this cell
#
# Exporting and installing the new version of the CLI command...
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///work/fastkafka
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: aiofiles>=22.1.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (23.1.0)
# Requirement already satisfied: aiokafka>=0.8.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (0.8.0)
# Requirement already satisfied: asyncer>=0.0.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (0.0.2)
# Requirement already satisfied: confluent-kafka>=1.9.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (2.0.2)
# Requirement already satisfied: docstring-parser>=0.15 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (0.15)
# Requirement already satisfied: fastcore>=1.5.27 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.1) (1.5.28)
# Requirement already satisfied: httpx>=0.23.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (0.23.3)
# Requirement already satisfied: install-jdk==0.3.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (0.3.0)
# Requirement already satisfied: ipywidgets>=8.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (8.0.4)
# Requirement already satisfied: nest-asyncio>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.1) (1.5.6)
# Requirement already satisfied: posix-ipc>=1.1.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (1.1.1)
# Requirement already satisfied: pydantic>=1.9 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (1.10.5)
# Requirement already satisfied: python-multipart>=0.0.5 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (0.0.6)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.1) (2.28.2)
# Requirement already satisfied: tqdm>=4.62 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (4.65.0)
# Requirement already satisfied: bandit==1.7.4 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (1.7.4)
# Requirement already satisfied: black==23.1.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (23.1.0)
# Requirement already satisfied: email-validator==1.3.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (1.3.1)
# Requirement already satisfied: isort==5.12.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (5.12.0)
# Requirement already satisfied: mypy==1.0.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (1.0.1)
# Requirement already satisfied: nbconvert==7.2.9 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.1) (7.2.9)
# Requirement already satisfied: nbdev-mkdocs==0.1.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (0.1.0)
# Requirement already satisfied: nbqa==1.6.3 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (1.6.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.1) (1.24.2)
# Requirement already satisfied: pandas>=1.2.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (1.5.3)
# Requirement already satisfied: pre-commit==3.0.4 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (3.0.4)
# Requirement already satisfied: pytest==7.2.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (7.2.1)
# Requirement already satisfied: scikit-learn==1.2.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (1.2.1)
# Requirement already satisfied: semgrep==1.12.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.1) (1.12.1)
# Requirement already satisfied: GitPython>=1.0.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from bandit==1.7.4->fastkafka==0.1.1) (3.1.31)
# Requirement already satisfied: stevedore>=1.20.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from bandit==1.7.4->fastkafka==0.1.1) (5.0.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from bandit==1.7.4->fastkafka==0.1.1) (6.0)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black==23.1.0->fastkafka==0.1.1) (3.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from black==23.1.0->fastkafka==0.1.1) (0.11.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from black==23.1.0->fastkafka==0.1.1) (2.0.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/tvrtko/.local/lib/python3.10/site-packages (from black==23.1.0->fastkafka==0.1.1) (1.0.0)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.10/dist-packages (from black==23.1.0->fastkafka==0.1.1) (23.0)
# Requirement already satisfied: click>=8.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from black==23.1.0->fastkafka==0.1.1) (8.1.3)
# Requirement already satisfied: dnspython>=1.15.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from email-validator==1.3.1->fastkafka==0.1.1) (2.3.0)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email-validator==1.3.1->fastkafka==0.1.1) (3.4)
# Requirement already satisfied: typing-extensions>=3.10 in /home/tvrtko/.local/lib/python3.10/site-packages (from mypy==1.0.1->fastkafka==0.1.1) (4.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (6.0.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (0.2.2)
# Requirement already satisfied: traitlets>=5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (5.9.0)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (0.7.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (2.14.0)
# Requirement already satisfied: mistune<3,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (2.0.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (4.11.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (1.2.1)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (5.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (0.7.1)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (2.1.2)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert==7.2.9->fastkafka==0.1.1) (5.7.3)
# Requirement already satisfied: docstring-gen>=0.2.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.2.2)
# Requirement already satisfied: mkdocstrings==0.18.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.18.1)
# Requirement already satisfied: mike>=1.1.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.1.2)
# Requirement already satisfied: mkdocs-literate-nav>=0.5.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.6.0)
# Requirement already satisfied: nbdev==2.3.12 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (2.3.12)
# Requirement already satisfied: mkdocs-section-index>=0.3.4 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.3.5)
# Requirement already satisfied: griffe>=0.24.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.25.5)
# Requirement already satisfied: mkdocs-material>=8.5.11 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (9.1.1)
# Requirement already satisfied: mkdocs>=1.4.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.4.2)
# Requirement already satisfied: typer[all]>=0.7.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.7.0)
# Requirement already satisfied: playwright>=1.28.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.31.1)
# Requirement already satisfied: configupdater>=3.1.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (3.1.1)
# Requirement already satisfied: ruamel.yaml>=0.17.21 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.17.21)
# Requirement already satisfied: openai>=0.25.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.27.0)
# Requirement already satisfied: tokenize-rt>=3.2.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbqa==1.6.3->fastkafka==0.1.1) (5.0.0)
# Requirement already satisfied: ipython>=7.8.0 in /usr/local/lib/python3.10/dist-packages (from nbqa==1.6.3->fastkafka==0.1.1) (8.10.0)
# Requirement already satisfied: cfgv>=2.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from pre-commit==3.0.4->fastkafka==0.1.1) (3.3.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from pre-commit==3.0.4->fastkafka==0.1.1) (20.20.0)
# Requirement already satisfied: nodeenv>=0.11.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from pre-commit==3.0.4->fastkafka==0.1.1) (1.7.0)
# Requirement already satisfied: identify>=1.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from pre-commit==3.0.4->fastkafka==0.1.1) (2.5.18)
# Requirement already satisfied: iniconfig in /home/tvrtko/.local/lib/python3.10/site-packages (from pytest==7.2.1->fastkafka==0.1.1) (2.0.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from pytest==7.2.1->fastkafka==0.1.1) (22.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/tvrtko/.local/lib/python3.10/site-packages (from pytest==7.2.1->fastkafka==0.1.1) (1.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/tvrtko/.local/lib/python3.10/site-packages (from pytest==7.2.1->fastkafka==0.1.1) (1.0.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from scikit-learn==1.2.1->fastkafka==0.1.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from scikit-learn==1.2.1->fastkafka==0.1.1) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from scikit-learn==1.2.1->fastkafka==0.1.1) (1.10.1)
# Requirement already satisfied: wcmatch~=8.3 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep==1.12.1->fastkafka==0.1.1) (8.4.1)
# Requirement already satisfied: click-option-group~=0.5 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep==1.12.1->fastkafka==0.1.1) (0.5.5)
# Requirement already satisfied: glom~=22.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep==1.12.1->fastkafka==0.1.1) (22.1.0)
# Requirement already satisfied: python-lsp-jsonrpc~=1.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep==1.12.1->fastkafka==0.1.1) (1.0.0)
# Requirement already satisfied: jsonschema~=4.6 in /usr/local/lib/python3.10/dist-packages (from semgrep==1.12.1->fastkafka==0.1.1) (4.17.3)
# Requirement already satisfied: rich>=12.6.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep==1.12.1->fastkafka==0.1.1) (12.6.0)
# Requirement already satisfied: colorama~=0.4.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep==1.12.1->fastkafka==0.1.1) (0.4.6)
# Requirement already satisfied: boltons~=21.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep==1.12.1->fastkafka==0.1.1) (21.0.0)
# Requirement already satisfied: peewee~=3.14 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep==1.12.1->fastkafka==0.1.1) (3.16.0)
# Requirement already satisfied: urllib3~=1.26 in /usr/local/lib/python3.10/dist-packages (from semgrep==1.12.1->fastkafka==0.1.1) (1.26.14)
# Requirement already satisfied: mkdocstrings-python-legacy>=0.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from mkdocstrings==0.18.1->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.2.2)
# Requirement already satisfied: Markdown>=3.3 in /home/tvrtko/.local/lib/python3.10/site-packages (from mkdocstrings==0.18.1->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (3.3.7)
# Requirement already satisfied: mkdocs-autorefs>=0.3.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from mkdocstrings==0.18.1->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.4.1)
# Requirement already satisfied: pymdown-extensions>=6.3 in /home/tvrtko/.local/lib/python3.10/site-packages (from mkdocstrings==0.18.1->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (9.10)
# Requirement already satisfied: asttokens in /usr/local/lib/python3.10/dist-packages (from nbdev==2.3.12->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (2.2.1)
# Requirement already satisfied: ghapi>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from nbdev==2.3.12->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.0.3)
# Requirement already satisfied: execnb>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from nbdev==2.3.12->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.1.5)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.10/dist-packages (from nbdev==2.3.12->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (2.2.1)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.10/dist-packages (from nbdev==2.3.12->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.6.3)
# Requirement already satisfied: kafka-python>=2.0.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from aiokafka>=0.8.0->fastkafka==0.1.1) (2.0.2)
# Requirement already satisfied: async-timeout in /home/tvrtko/.local/lib/python3.10/site-packages (from aiokafka>=0.8.0->fastkafka==0.1.1) (4.0.2)
# Requirement already satisfied: anyio<4.0.0,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from asyncer>=0.0.2->fastkafka==0.1.1) (3.6.2)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from fastcore>=1.5.27->fastkafka==0.1.1) (23.0.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastkafka==0.1.1) (1.3.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from httpx>=0.23.0->fastkafka==0.1.1) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/tvrtko/.local/lib/python3.10/site-packages (from httpx>=0.23.0->fastkafka==0.1.1) (1.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastkafka==0.1.1) (2022.12.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from ipywidgets>=8.0->fastkafka==0.1.1) (3.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0->fastkafka==0.1.1) (6.21.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from ipywidgets>=8.0->fastkafka==0.1.1) (4.0.5)
# Requirement already satisfied: pytz>=2020.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from pandas>=1.2.0->fastkafka==0.1.1) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->fastkafka==0.1.1) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->fastkafka==0.1.1) (3.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from GitPython>=1.0.1->bandit==1.7.4->fastkafka==0.1.1) (4.0.10)
# Requirement already satisfied: face>=20.1.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from glom~=22.1->semgrep==1.12.1->fastkafka==0.1.1) (22.0.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tvrtko/.local/lib/python3.10/site-packages (from httpcore<0.17.0,>=0.15.0->httpx>=0.23.0->fastkafka==0.1.1) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.1) (0.1.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.1) (5.9.4)
# Requirement already satisfied: pyzmq>=20 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.1) (25.0.0)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.1) (6.2)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.1) (1.6.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.1) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.1) (8.0.3)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (0.18.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (3.0.37)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (5.1.1)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (0.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema~=4.6->semgrep==1.12.1->fastkafka==0.1.1) (0.19.3)
# Requirement already satisfied: verspec in /home/tvrtko/.local/lib/python3.10/site-packages (from mike>=1.1.2->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.1.0)
# Requirement already satisfied: ghp-import>=1.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from mkdocs>=1.4.2->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (2.1.0)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from mkdocs>=1.4.2->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.1)
# Requirement already satisfied: mergedeep>=1.3.4 in /home/tvrtko/.local/lib/python3.10/site-packages (from mkdocs>=1.4.2->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.3.4)
# Requirement already satisfied: regex>=2022.4.24 in /home/tvrtko/.local/lib/python3.10/site-packages (from mkdocs-material>=8.5.11->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (2022.10.31)
# Requirement already satisfied: mkdocs-material-extensions>=1.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from mkdocs-material>=8.5.11->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.1.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert==7.2.9->fastkafka==0.1.1) (2.16.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nodeenv>=0.11.1->pre-commit==3.0.4->fastkafka==0.1.1) (59.6.0)
# Requirement already satisfied: aiohttp in /home/tvrtko/.local/lib/python3.10/site-packages (from openai>=0.25.0->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (3.8.4)
# Requirement already satisfied: greenlet==2.0.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from playwright>=1.28.0->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (2.0.1)
# Requirement already satisfied: pyee==9.0.4 in /home/tvrtko/.local/lib/python3.10/site-packages (from playwright>=1.28.0->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (9.0.4)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->fastkafka==0.1.1) (1.16.0)
# Requirement already satisfied: ujson>=3.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from python-lsp-jsonrpc~=1.0.0->semgrep==1.12.1->fastkafka==0.1.1) (5.7.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from rich>=12.6.0->semgrep==1.12.1->fastkafka==0.1.1) (0.9.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /home/tvrtko/.local/lib/python3.10/site-packages (from ruamel.yaml>=0.17.21->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.2.7)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from stevedore>=1.20.0->bandit==1.7.4->fastkafka==0.1.1) (5.11.1)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from typer[all]>=0.7.0->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.5.0.post1)
# Requirement already satisfied: filelock<4,>=3.4.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit==3.0.4->fastkafka==0.1.1) (3.9.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /home/tvrtko/.local/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit==3.0.4->fastkafka==0.1.1) (0.3.6)
# Requirement already satisfied: bracex>=2.1.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from wcmatch~=8.3->semgrep==1.12.1->fastkafka==0.1.1) (2.3.post1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert==7.2.9->fastkafka==0.1.1) (2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert==7.2.9->fastkafka==0.1.1) (0.5.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.1->bandit==1.7.4->fastkafka==0.1.1) (5.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (0.8.3)
# Requirement already satisfied: pytkdocs>=0.14 in /home/tvrtko/.local/lib/python3.10/site-packages (from mkdocstrings-python-legacy>=0.2->mkdocstrings==0.18.1->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.16.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (0.2.6)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from aiohttp->openai>=0.25.0->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from aiohttp->openai>=0.25.0->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tvrtko/.local/lib/python3.10/site-packages (from aiohttp->openai>=0.25.0->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from aiohttp->openai>=0.25.0->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (1.3.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse->nbdev==2.3.12->nbdev-mkdocs==0.1.0->fastkafka==0.1.1) (0.37.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=7.8.0->nbqa==1.6.3->fastkafka==0.1.1) (1.2.0)
# Installing collected packages: fastkafka
#   Attempting uninstall: fastkafka
#     Found existing installation: fastkafka 0.1.1
#     Uninstalling fastkafka-0.1.1:
#       Successfully uninstalled fastkafka-0.1.1
#   Running setup.py develop for fastkafka
# Successfully installed fastkafka
# ok

# %%
# | export


async def terminate_asyncio_process(p: asyncio.subprocess.Process) -> None:
    logger.info(f"terminate_asyncio_process(): Terminating the process {p.pid}...")
    # Check if SIGINT already propagated to process
    try:
        await asyncio.wait_for(p.wait(), 1)
        logger.info(
            f"terminate_asyncio_process(): Process {p.pid} was already terminated."
        )
        return
    except asyncio.TimeoutError:
        pass

    for i in range(3):
        p.terminate()
        try:
            await asyncio.wait_for(p.wait(), 10)
            logger.info(f"terminate_asyncio_process(): Process {p.pid} terminated.")
            return
        except asyncio.TimeoutError:
            logger.warning(
                f"terminate_asyncio_process(): Process {p.pid} not terminated, retrying..."
            )

    logger.warning(f"Killing the process {p.pid}...")
    p.kill()
    await p.wait()
    logger.warning(f"terminate_asyncio_process(): Process {p.pid} killed!")

# %%
with generate_app_in_tmp() as app:
    async with LocalKafkaBroker(listener_port=9099) as bootstrap_server:
        host_port = bootstrap_server.split(":")
        os.environ["KAFKA_HOSTNAME"] = host_port[0]
        os.environ["KAFKA_PORT"] = host_port[1]
        proc = await asyncio.create_subprocess_exec(
            "run_fastkafka_server_process", app, stdout=asyncio.subprocess.PIPE
        )
        sleep(5)
        await terminate_asyncio_process(proc)
        outputs, _ = await proc.communicate()

        print(outputs.decode("utf-8"))
        assert proc.returncode == 0
# Out:
# [INFO] fastkafka._testing.local_broker: Java is already installed.
# [INFO] fastkafka._testing.local_broker: But not exported to PATH, exporting...
# [INFO] fastkafka._testing.local_broker: Kafka is already installed.
# [INFO] fastkafka._testing.local_broker: But not exported to PATH, exporting...
# [INFO] fastkafka._testing.local_broker: Starting zookeeper...
# [INFO] fastkafka._testing.local_broker: zookeeper started, sleeping for 5 seconds...
# [INFO] fastkafka._testing.local_broker: Starting kafka...
# [INFO] fastkafka._testing.local_broker: kafka started, sleeping for 5 seconds...
# [INFO] fastkafka._testing.local_broker: Local Kafka broker up and running on 127.0.0.1:9099
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 279627...
# [INFO] __main__: terminate_asyncio_process(): Process 279627 terminated.
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:9099'}'
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:9099', 'group_id': '127.0.0.1:9099_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:9099', 'group_id': '127.0.0.1:9099_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:9099_group' (generation 1) with member_id aiokafka-0.8.0-fb8921b3-8e30-4c38-b227-059284e859ef
# [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [WARNING] kafka.coordinator.assignors.roundrobin: No partition metadata for topic realitime_data
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:9099_group with generation 1
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:9099_group' (generation 2) with member_id aiokafka-0.8.0-e55f4208-d605-4a34-9504-65e28aaf944d
# [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:9099_group with generation 2
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:9099_group
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
#
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 279212...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 279212 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 278847...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 278847 terminated.

# %%
# | export


async def run_fastkafka_server(num_workers: int, app: str) -> None:
    loop = asyncio.get_event_loop()

    HANDLED_SIGNALS = (
        signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
        signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
    )

    d = {"should_exit": False}

    def handle_exit(sig: int, d: Dict[str, bool] = d) -> None:
        d["should_exit"] = True

    for sig in HANDLED_SIGNALS:
        loop.add_signal_handler(sig, handle_exit, sig)

    async with asyncer.create_task_group() as tg:
        tasks = [
            tg.soonify(asyncio.create_subprocess_exec)(
                "run_fastkafka_server_process",
                app,
                stdout=asyncio.subprocess.PIPE,
                stdin=asyncio.subprocess.PIPE,
            )
            for i in range(num_workers)
        ]

    procs = [task.value for task in tasks]

    async def log_output(
        output: Optional[asyncio.StreamReader], pid: int, d: Dict[str, bool] = d
    ) -> None:
        if output is None:
            raise RuntimeError("Expected StreamReader, got None. Is stdout piped?")
        while not output.at_eof():
            outs = await output.readline()
            if outs != b"":
                typer.echo(f"[{pid:03d}]: " + outs.decode("utf-8"), nl=False)

    async with asyncer.create_task_group() as tg:
        for proc in procs:
            tg.soonify(log_output)(proc.stdout, proc.pid)

        while not d["should_exit"]:
            await asyncio.sleep(0.2)

        typer.echo("Starting process cleanup, this may take a few seconds...")
        for proc in procs:
            tg.soonify(terminate_asyncio_process)(proc)

    for proc in procs:
        output, _ = await proc.communicate()
        if output:
            typer.echo(f"[{proc.pid:03d}]: " + output.decode("utf-8"), nl=False)

    returncodes = [proc.returncode for proc in procs]
    if not returncodes == [0] * len(procs):
        typer.secho(
            f"Return codes are not all zero: {returncodes}",
            err=True,
            fg=typer.colors.RED,
        )
        raise typer.Exit(1)

# %%
# | export


@contextmanager
def run_in_process(
    target: Callable[..., Any]
) -> Generator[multiprocessing.Process, None, None]:
    p = multiprocessing.Process(target=target)
    try:
        p.start()
        yield p
    except Exception as e:
        print(f"Exception raised {e=}")
    finally:
        p.terminate()
        p.join()

# %%
# | notest

async with LocalKafkaBroker(listener_port=10000) as bootstrap_server:
    host_port = bootstrap_server.split(":")
    os.environ["KAFKA_HOSTNAME"] = host_port[0]
    os.environ["KAFKA_PORT"] = host_port[1]

    with generate_app_in_tmp() as app:

        def run_fastkafka_server_test():
            asyncio.run(run_fastkafka_server(4, app))

        with run_in_process(run_fastkafka_server_test) as p:
            sleep(15)

        assert p.exitcode == 0, p.exitcode
        p.close()

print("ok")
# Out:
# [INFO] fastkafka._testing.local_broker: Java is already installed.
# [INFO] fastkafka._testing.local_broker: Kafka is already installed.
# [INFO] fastkafka._testing.local_broker: Starting zookeeper...
# [INFO] fastkafka._testing.local_broker: zookeeper started, sleeping for 5 seconds...
# [INFO] fastkafka._testing.local_broker: Starting kafka...
# [INFO] fastkafka._testing.local_broker: kafka started, sleeping for 5 seconds...
# [INFO] fastkafka._testing.local_broker: Local Kafka broker up and running on 127.0.0.1:10000
# [281803]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281805]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281807]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281803]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281805]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281803]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281807]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281803]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [281805]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281805]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281807]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281809]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [281803]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [281803]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [281803]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [281803]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281807]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [281807]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [281807]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [281807]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [281807]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [281805]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [281805]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [281805]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [281805]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281809]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281809]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281809]: [INFO] fastkafka._application.app: _create_producer() : created producer using the config: '{'bootstrap_servers': '127.0.0.1:10000'}'
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': '127.0.0.1:10000', 'group_id': '127.0.0.1:10000_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [281809]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [281809]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [281809]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [281809]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281809]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281809]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281809]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281803]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [ERROR] aiokafka.cluster: Topic training_data not found in cluster metadata
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281805]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281805]: [WARNING] aiokafka.cluster: Topic training_data is not available during auto-create initialization
# [281807]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281807]: [WARNING] aiokafka.cluster: Topic realitime_data is not available during auto-create initialization
# [281809]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [ERROR] aiokafka.cluster: Topic realitime_data not found in cluster metadata
# [281803]: [ERROR] aiokafka.consumer.group_coordinator: Group Coordinator Request failed: [Error 15] CoordinatorNotAvailableError
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [281809]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-1633a7bb-83e1-4090-a76a-4cab79db04ed
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {} to {'training_data': 1, 'realitime_data': 1}.
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-4a27292f-b3de-45bd-8304-33927ffa8b4e
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-0876af66-68f3-4f71-a7d0-550026bf69ad
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-cf7c9e2b-a4b3-4d20-9f22-46ec58a9c7dc
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 1) with member_id aiokafka-0.8.0-df0e12e0-c627-4860-bd18-501a0904dcc7
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [281809]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 0 for group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:10000_group
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 1
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [281805]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [281807]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset() for group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281805]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset() for group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281803]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [281809]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group 127.0.0.1:10000_group because it is rebalancing
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset() for group 127.0.0.1:10000_group
# [281809]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='realitime_data', partition=0)}) for group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='training_data', partition=0)}) for group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-1633a7bb-83e1-4090-a76a-4cab79db04ed
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-0876af66-68f3-4f71-a7d0-550026bf69ad
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-4a27292f-b3de-45bd-8304-33927ffa8b4e
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-df0e12e0-c627-4860-bd18-501a0904dcc7
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-b63ee0d3-6149-4e84-9334-4b6e20837a79
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-3e827dd0-4393-42ba-b4d8-418f246ad2c1
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-cf7c9e2b-a4b3-4d20-9f22-46ec58a9c7dc
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Joined group '127.0.0.1:10000_group' (generation 2) with member_id aiokafka-0.8.0-7609bfe6-ee43-404d-ac08-585b5872c4da
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [281807]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group 127.0.0.1:10000_group
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [281803]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [281805]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group 127.0.0.1:10000_group with generation 2
# [281809]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group 127.0.0.1:10000_group
# Starting process cleanup, this may take a few seconds...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 281803...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 281805...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 281807...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 281809...
# [281809]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [281809]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [281809]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [281807]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [281807]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [281807]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [281803]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [281803]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [281803]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [281805]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [281805]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [281805]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] __main__: terminate_asyncio_process(): Process 281809 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 281805 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 281803 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 281807 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 281388...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 281388 terminated.
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Terminating the process 281023...
# [INFO] fastkafka._components._subprocess: terminate_asyncio_process(): Process 281023 terminated.
# ok
