# %%
#| default_exp uvicorn_helpers

# %%
#| export


from typing import *
from contextlib import contextmanager

import multiprocessing

from fastapi import FastAPI
from uvicorn import Config, Server

# %%
from fast_kafka_api.application import FastKafka
from time import sleep

# %%
#| notest 

import nest_asyncio

nest_asyncio.apply()

# %%
#| export

@contextmanager
def run_uvicorn(arg: Union[Config, FastAPI]) -> Generator[None, None, None]:
    if isinstance(arg, Config):
        config: Config = arg
    else:
        config=Config(app=arg)

    def run(config=config):
        server = Server(config=config)
        server.run()
        
    p = multiprocessing.Process(target=run)
    try:
        p.start()
        yield
    except Exception as e:
        print(f"Exception raised {e=}")
    finally:
        p.terminate()
        p.join()
        p.close()

# %%
app = FastAPI()
fast_kafka = FastKafka(app, )

with run_uvicorn(Config(app=app)):
    print("UvicornServer running") 
    sleep(2)  # Start timeout
    print("UvicornServer exiting")

print("exited")
print("ok")
# Out:
# INFO:     Started server process [5426]
# INFO:     Waiting for application startup.
# [INFO] fast_kafka_api._components.asyncapi: Keeping the old async specifications at: '/work/fast-kafka-api/nbs/asyncapi/spec/asyncapi.yml'
# [INFO] fast_kafka_api._components.asyncapi: Skipping generating async documentation in '/work/fast-kafka-api/nbs/asyncapi/docs'
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# UvicornServer running
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [5426]
# UvicornServer exiting
# exited
# ok
