# %%
# | default_exp __init__

# %%
# | export

from fastkafka._application.app import FastKafka

__all__ = [
    "FastKafka",
]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # | export
# ----> 3 from fastkafka._application.app import (logger, FastKafka, produce_decorator, AwaitedMock, Tester, mirror_producer, mirror_consumer)
#
# ModuleNotFoundError: No module named 'fastkafka._application'

# %%
# | export


def dummy() -> None:
    pass


dummy.__module__ = "_dummy"
