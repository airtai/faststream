# %%
# | default_exp server

# %%
# | export

import importlib
import sys
import asyncio
from typing import *
from contextlib import contextmanager
from pathlib import Path
import threading
import signal
from contextlib import ExitStack, contextmanager
from tempfile import TemporaryDirectory
import subprocess


import multiprocessing
from fastcore.meta import delegates
from fastcore.basics import patch
import typer
from anyio import create_task_group

from fastkafka.application import FastKafka
from fastkafka.testing import change_dir
from fastkafka._components.helpers import _import_from_string, generate_app_src
from fastkafka._components.logger import get_logger

# %%
import os
from time import sleep
from pydantic import BaseModel
from fastkafka._components.logger import supress_timestamps

# %%
# | notest

# allows async calls in notebooks

import nest_asyncio

# %%
# | notest

nest_asyncio.apply()

# %%
# | export

logger = get_logger(__name__)

# %%
supress_timestamps()
logger = get_logger(__name__, level=20)
logger.info("ok")
# Out:
# [INFO] __main__: ok

# %%
def create_test_app():
    app = FastKafka(bootstrap_servers="tvrtko-fastkafka-kafka-1:9092")

    class MyMessage(BaseModel):
        msg: str

    @app.consumes()
    def on_my_topic(msg: MyMessage):
        pass
    
    return app

# %%
# | export

@contextmanager
def generate_app_in_tmp() -> Generator[None, None, None]:
    with TemporaryDirectory() as d:
        src_path = Path(d) / "main.py"
        generate_app_src(src_path)
        with change_dir(d):
            import_str = f"{src_path.stem}:kafka_app"
            yield import_str

# %%
# | export


class ServerProcess:
    def __init__(self, app: str):
        self.app = app
        self.should_exit = False

    def run(self) -> None:
        return asyncio.run(self._serve())

    async def _serve(self) -> None:
        self._install_signal_handlers()

        self.application = _import_from_string(self.app)

        async with self.application:
            await self._main_loop()

    def _install_signal_handlers(self) -> None:
        if threading.current_thread() is not threading.main_thread():
            raise RuntimeError()

        loop = asyncio.get_event_loop()

        HANDLED_SIGNALS = (
            signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
            signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
        )

        def handle_exit(sig: int) -> None:
            self.should_exit = True

        for sig in HANDLED_SIGNALS:
            loop.add_signal_handler(sig, handle_exit, sig)

    async def _main_loop(self) -> None:
        while not self.should_exit:
            await asyncio.sleep(0.1)

def terminate_process(p: Union[subprocess.Popen]) -> Tuple[bytes, bytes]:
    for i in range(3):
        p.terminate()
        try:
            p.wait(timeout=10)
            return p.communicate()

        except subprocess.TimeoutExpired:
            logger.warning("Process not terminated, retrying...")

    logger.warning("Killing the process...")
    p.kill()
    p.wait()
    outs, errs = p.communicate()
    logger.warning("Process killed!")

    return outs, errs


_app = typer.Typer()


@_app.command()
def run_fastkafka_server_process(
    app: str = typer.Argument(
        ...,
        help="input in the form of 'path:app', where **path** is the path to a python file and **app** is an object of type **FastKafka**.",
    )
) -> None:
    ServerProcess(app).run()

# %%
# | notest

print("WARNING: make sure you save the notebook before running this cell\n")

print("Exporting and installing the new version of the CLI command...")
subprocess.run(["nbdev_export"], check=True, capture_output=True)
subprocess.run(["pip", "install", "-e", "..[dev]"], check=True, capture_output=True)

print("ok")
# Out:
# WARNING: make sure you save the notebook before running this cell
#
# Exporting and installing the new version of the CLI command...
# ok

# %%
#| export


async def terminate_asyncio_process(p: asyncio.subprocess.Process) -> Tuple[bytes, bytes]:
    for i in range(3):
        p.terminate()
        try:
            return await asyncio.wait_for(p.communicate(), 10)
        
        except subprocess.TimeoutExpired:
            logger.warning("Process not terminated, retrying...")

    logger.warning("Killing the process...")
    p.kill()
    outs, errs = await p.communicate()
    logger.warning("Process killed!")

    return outs, errs

# %%
with generate_app_in_tmp() as app:
    proc = await asyncio.create_subprocess_exec(
                "run_fastkafka_server_process", app, stdout=asyncio.subprocess.PIPE
            )
    sleep(5)
    outputs, _ = await terminate_asyncio_process(proc)
    
    print(outputs.decode("utf-8"))
    assert proc.returncode == 0
# Out:
# [INFO] main: check
# [INFO] fastkafka._components.asyncapi: Old async specifications at '/tmp/tmpdpt9uggj/asyncapi/spec/asyncapi.yml' does not exist.
# [INFO] fastkafka._components.asyncapi: New async specifications generated at: '/tmp/tmpdpt9uggj/asyncapi/spec/asyncapi.yml'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 64) with member_id aiokafka-0.8.0-93056f89-e4ad-4abd-879c-f2f936af17fd
# [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 64) with member_id aiokafka-0.8.0-6128a4fb-b5b4-41de-8a19-fb879e06436d
# [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {} to {'training_data': 1, 'realitime_data': 1}.
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 64
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 64
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.

# %%
# | export


async def run_fastkafka_server(num_workers: int, app: str):
    loop = asyncio.get_event_loop()

    HANDLED_SIGNALS = (
        signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
        signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
    )

    d = {"should_exit": False}

    def handle_exit(sig: int, d: Dict[str, bool] = d) -> None:
        d["should_exit"] = True

    for sig in HANDLED_SIGNALS:
        loop.add_signal_handler(sig, handle_exit, sig)

    procs = [
        await asyncio.create_subprocess_exec(
            "run_fastkafka_server_process", app, stdout=asyncio.subprocess.PIPE
        )
        for i in range(num_workers)
    ]
    
    async def log_output(output: asyncio.StreamReader, worker_id: int, d: Dict[str, bool] = d) -> None:
        while not d["should_exit"]:
            outs = await output.read(n=1024)
            if outs != b"":
                typer.echo(f"[{worker_id:03d}]: " + outs.decode("utf-8"), nl=False)
    
    async with create_task_group() as tg:
        log_tasks = [tg.start_soon(log_output, proc.stdout, i) for i, proc in enumerate(procs)]
        while not d["should_exit"]:
            await asyncio.sleep(0.2)

#     terminate and stuff
#     outputs = [await terminate_asyncio_process(proc) for proc in procs]
    [await proc.wait() for proc in procs]
    outputs = [await proc.communicate() for proc in procs]

    for i, (output, _) in enumerate(outputs):
        typer.echo(f"[{i:03d}]: " + output.decode("utf-8"))

    returncodes = [proc.returncode for proc in procs]
    if not returncodes == [0] * len(procs):
        typer.secho(
            f"Return codes are not all zero: {returncodes}",
            err=True,
            fg=typer.colors.RED,
        )
        raise typer.Exit(1)

# %%
# | notest

with generate_app_in_tmp() as app:
    print(f"{app=}")
    await run_fastkafka_server(4, app)

print("ok")
# Out:
# app='main:kafka_app'
# [003]: [INFO] main: check
# [003]: [INFO] fastkafka._components.asyncapi: Old async specifications at '/tmp/tmpepdntixw/asyncapi/spec/asyncapi.yml' does not exist.
# [003]: [INFO] fastkafka._components.asyncapi: New async specifications generated at: '/tmp/tmpepdntixw/asyncapi/spec/asyncapi.yml'
# [003]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [003]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [003]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [002]: [INFO] main: check
# [003]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [003]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [003]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [003]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [003]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [003]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [003]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [003]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [003]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [003]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [003]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [003]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [003]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [003]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [003]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 66) with member_id aiokafka-0.8.0-4c4063a4-a503-47c1-8a0c-917a48f7c879
# [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 66
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [003]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [003]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [003]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [000]: [INFO] main: check
# [002]: [INFO] fastkafka._components.asyncapi: Keeping the old async specifications at: '/tmp/tmpepdntixw/asyncapi/spec/asyncapi.yml'
# [002]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [002]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [001]: [INFO] main: check
# [002]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [002]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [002]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [002]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [002]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [002]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [002]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [002]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [002]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [002]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [002]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [002]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [000]: [INFO] fastkafka._components.asyncapi: Keeping the old async specifications at: '/tmp/tmpepdntixw/asyncapi/spec/asyncapi.yml'
# [000]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [000]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [001]: [INFO] fastkafka._components.asyncapi: Keeping the old async specifications at: '/tmp/tmpepdntixw/asyncapi/spec/asyncapi.yml'
# [001]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [001]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [000]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [000]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [000]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [000]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [000]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [000]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [001]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [000]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [000]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [000]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [001]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [001]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [000]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [001]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [000]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [001]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [001]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [001]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [001]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [001]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [001]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [001]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [001]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [001]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [001]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [001]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [001]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [003]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group tvrtko-fastkafka-kafka-1:9092_group because it is rebalancing
# [003]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='training_data', partition=0)}) for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [000]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 67) with member_id aiokafka-0.8.0-7a2fc8e2-3810-4f95-acb5-38110417efde
# [002]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 67) with member_id aiokafka-0.8.0-fe33380d-b63f-469d-8180-fcd2f9c35623
# [001]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 67) with member_id aiokafka-0.8.0-e6428a02-3ac2-409d-b094-5829b870e51a
# [003]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 67) with member_id aiokafka-0.8.0-4c4063a4-a503-47c1-8a0c-917a48f7c879
# [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [001]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 67) with member_id aiokafka-0.8.0-8f567320-0e82-4f40-b8cc-95b176e7dfff
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 67
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 67
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [002]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 67) with member_id aiokafka-0.8.0-3659ebf4-0595-4b67-93aa-4844abe396e1
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 67
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 67
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [003]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 67) with member_id aiokafka-0.8.0-c1463e54-194d-405d-8624-ccc61c930d4d
# [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {'training_data': 1} to {'training_data': 1, 'realitime_data': 1}.
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 67
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [000]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 67) with member_id aiokafka-0.8.0-76b8b464-a358-47d0-b652-22d834883910
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 67
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 67
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [003]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 67
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [002]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [001]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [003]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [000]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [000]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
#
# [001]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
#
# [002]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
#
# [003]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
#
# ok
