# %%
# | default_exp server

# %%
# | export

import importlib
import sys
import asyncio
from typing import *
from contextlib import contextmanager
from pathlib import Path
import threading
import signal
from contextlib import ExitStack, contextmanager
from tempfile import TemporaryDirectory
import subprocess


import multiprocessing
from fastcore.meta import delegates
from fastcore.basics import patch
import typer
import asyncer

from fastkafka.application import FastKafka
from fastkafka.testing import change_dir
from fastkafka._components.helpers import _import_from_string, generate_app_src
from fastkafka._components.logger import get_logger

# %%
import os
from time import sleep
from pydantic import BaseModel
from fastkafka._components.logger import supress_timestamps

# %%
# | notest

# allows async calls in notebooks

import nest_asyncio

# %%
# | notest

nest_asyncio.apply()

# %%
# | export

logger = get_logger(__name__)

# %%
supress_timestamps()
logger = get_logger(__name__, level=20)
logger.info("ok")
# Out:
# [INFO] __main__: ok

# %%
def create_test_app():
    app = FastKafka(bootstrap_servers="tvrtko-fastkafka-kafka-1:9092")

    class MyMessage(BaseModel):
        msg: str

    @app.consumes()
    def on_my_topic(msg: MyMessage):
        pass
    
    return app

# %%
# | export

@contextmanager
def generate_app_in_tmp() -> Generator[str, None, None]:
    with TemporaryDirectory() as d:
        src_path = Path(d) / "main.py"
        generate_app_src(src_path)
        with change_dir(d):
            import_str = f"{src_path.stem}:kafka_app"
            yield import_str

# %%
# | export


class ServerProcess:
    def __init__(self, app: str):
        self.app = app
        self.should_exit = False

    def run(self) -> None:
        return asyncio.run(self._serve())

    async def _serve(self) -> None:
        self._install_signal_handlers()

        self.application = _import_from_string(self.app)

        async with self.application:
            await self._main_loop()

    def _install_signal_handlers(self) -> None:
        if threading.current_thread() is not threading.main_thread():
            raise RuntimeError()

        loop = asyncio.get_event_loop()

        HANDLED_SIGNALS = (
            signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
            signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
        )

        def handle_exit(sig: int) -> None:
            self.should_exit = True

        for sig in HANDLED_SIGNALS:
            loop.add_signal_handler(sig, handle_exit, sig)

    async def _main_loop(self) -> None:
        while not self.should_exit:
            await asyncio.sleep(0.1)

# %%
# | export

_app = typer.Typer()


@_app.command()
def run_fastkafka_server_process(
    app: str = typer.Argument(
        ...,
        help="input in the form of 'path:app', where **path** is the path to a python file and **app** is an object of type **FastKafka**.",
    )
) -> None:
    ServerProcess(app).run()

# %%
# | notest

print("WARNING: make sure you save the notebook before running this cell\n")

print("Exporting and installing the new version of the CLI command...")
subprocess.run(["nbdev_export"], check=True, capture_output=True)
subprocess.run(["pip", "install", "-e", "..[dev]"], check=True, capture_output=True)

print("ok")
# Out:
# WARNING: make sure you save the notebook before running this cell
#
# Exporting and installing the new version of the CLI command...
# ok

# %%
#| export


async def terminate_asyncio_process(p: asyncio.subprocess.Process) -> None:
    logger.info(f"terminate_asyncio_process(): Terminating the process {p.pid}...")
    # Check if SIGINT already propagated to process
    try:
        await asyncio.wait_for(p.wait(), 1)      
        logger.info(f"terminate_asyncio_process(): Process {p.pid} was already terminated.")
        return
    except asyncio.TimeoutError:
        pass
    
    for i in range(3):
        p.terminate()
        try:
            await asyncio.wait_for(p.wait(), 10)
            logger.info(f"terminate_asyncio_process(): Process {p.pid} terminated.")
            return
        except asyncio.TimeoutError:
            logger.warning(f"terminate_asyncio_process(): Process {p.pid} not terminated, retrying...")

    logger.warning(f"Killing the process {p.pid}...")
    p.kill()
    await p.wait()
    logger.warning(f"terminate_asyncio_process(): Process {p.pid} killed!")

# %%
with generate_app_in_tmp() as app:
    proc = await asyncio.create_subprocess_exec(
                "run_fastkafka_server_process", app, stdout=asyncio.subprocess.PIPE
            )
    sleep(5)
    await terminate_asyncio_process(proc)
    outputs, _ = await proc.communicate()
    
    print(outputs.decode("utf-8"))
    assert proc.returncode == 0
# Out:
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 1657...
# [INFO] __main__: terminate_asyncio_process(): Process 1657 terminated.
# [INFO] main: check
# [INFO] fastkafka._components.asyncapi: Old async specifications at '/tmp/tmp1c90mdyk/asyncapi/spec/asyncapi.yml' does not exist.
# [INFO] fastkafka._components.asyncapi: New async specifications generated at: '/tmp/tmp1c90mdyk/asyncapi/spec/asyncapi.yml'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 96) with member_id aiokafka-0.8.0-3f6f05af-732b-40bd-9ac8-eac9aadbceb3
# [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 96) with member_id aiokafka-0.8.0-e34bb89c-080b-428c-93e4-20a28ad449b6
# [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {} to {'realitime_data': 1, 'training_data': 1}.
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 96
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 96
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.

# %%
# | export

async def run_fastkafka_server(num_workers: int, app: str) -> None:
    loop = asyncio.get_event_loop()

    HANDLED_SIGNALS = (
        signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
        signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
    )

    d = {"should_exit": False}

    def handle_exit(sig: int, d: Dict[str, bool] = d) -> None:
        d["should_exit"] = True

    for sig in HANDLED_SIGNALS:
        loop.add_signal_handler(sig, handle_exit, sig)

    async with asyncer.create_task_group() as tg:
        tasks = [
            tg.soonify(asyncio.create_subprocess_exec)(
                "run_fastkafka_server_process", app, stdout=asyncio.subprocess.PIPE, stdin=asyncio.subprocess.PIPE
            )
            for i in range(num_workers)
        ]
        
    procs = [task.value for task in tasks]

    async def log_output(output: Optional[asyncio.StreamReader], pid: int, d: Dict[str, bool] = d) -> None:
        if output is None:
            raise RuntimeError("Expected StreamReader, got None. Is stdout piped?")
        while not output.at_eof():
            outs = await output.readline()
            if outs != b"":
                typer.echo(f"[{pid:03d}]: " + outs.decode("utf-8"), nl=False)
    
    async with asyncer.create_task_group() as tg:
        for proc in procs:
            tg.soonify(log_output)(proc.stdout, proc.pid)
            
        while not d["should_exit"]:
            await asyncio.sleep(0.2)
            
        typer.echo("Starting process cleanup, this may take a few seconds...")
        for proc in procs:
            tg.soonify(terminate_asyncio_process)(proc)
        
    for proc in procs:
        output, _ = await proc.communicate()
        if output:
            typer.echo(f"[{proc.pid:03d}]: " + output.decode("utf-8"), nl=False)

    returncodes = [proc.returncode for proc in procs]
    if not returncodes == [0] * len(procs):
        typer.secho(
            f"Return codes are not all zero: {returncodes}",
            err=True,
            fg=typer.colors.RED,
        )
        raise typer.Exit(1)

# %%
#| export

@contextmanager
def run_in_process(target: Callable[..., Any]) -> Generator[multiprocessing.Process, None, None]:
    p = multiprocessing.Process(target=target)
    try:
        p.start()
        yield p
    except Exception as e:
        print(f"Exception raised {e=}")
    finally:
        p.terminate()
        p.join()

# %%
with generate_app_in_tmp() as app:
    def run_fastkafka_server_test():
        asyncio.run(run_fastkafka_server(4, app))

    with run_in_process(run_fastkafka_server_test) as p:
        sleep(5)
        
    assert p.exitcode == 0
    p.close()
    
print("ok")
# Out:
# [2032]: [INFO] main: check
# [2028]: [INFO] main: check
# [2032]: [INFO] fastkafka._components.asyncapi: Old async specifications at '/tmp/tmp4qv859as/asyncapi/spec/asyncapi.yml' does not exist.
# [2032]: [INFO] fastkafka._components.asyncapi: New async specifications generated at: '/tmp/tmp4qv859as/asyncapi/spec/asyncapi.yml'
# [2032]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2034]: [INFO] main: check
# [2032]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2032]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2032]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [2032]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [2032]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [2032]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [2032]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2032]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 102) with member_id aiokafka-0.8.0-72f72e32-2e92-4506-8ec4-b20a2cb34a83
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [2028]: [INFO] fastkafka._components.asyncapi: Keeping the old async specifications at: '/tmp/tmp4qv859as/asyncapi/spec/asyncapi.yml'
# [2028]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 102
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2032]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [2028]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2034]: [INFO] fastkafka._components.asyncapi: Keeping the old async specifications at: '/tmp/tmp4qv859as/asyncapi/spec/asyncapi.yml'
# [2034]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2034]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2028]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2028]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [2028]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [2028]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [2028]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [2028]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [2028]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [2028]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2028]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [2028]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [2028]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2028]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [2034]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2034]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [2034]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [2034]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [2034]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [2034]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [2034]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [2034]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2034]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [2034]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [2034]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2034]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [2030]: [INFO] main: check
# [2030]: [INFO] fastkafka._components.asyncapi: Keeping the old async specifications at: '/tmp/tmp4qv859as/asyncapi/spec/asyncapi.yml'
# [2030]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2030]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2030]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2030]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [2030]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [2030]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [2030]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [2030]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [2030]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [2030]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2030]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [2030]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1001 for group tvrtko-fastkafka-kafka-1:9092_group
# [2030]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2030]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [2032]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group tvrtko-fastkafka-kafka-1:9092_group because it is rebalancing
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='training_data', partition=0)}) for group tvrtko-fastkafka-kafka-1:9092_group
# [2032]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [2028]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 103) with member_id aiokafka-0.8.0-0bb6a413-9d28-4460-9918-bc6329c6ec5c
# [2028]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 103) with member_id aiokafka-0.8.0-a693f941-3b5c-4ef8-b591-dc7abe498833
# [2030]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 103) with member_id aiokafka-0.8.0-d38441cb-6511-4280-b6c9-8b8c7797b200
# [2030]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 103) with member_id aiokafka-0.8.0-267088f1-9f7a-4296-8c65-0ebe41270e22
# [2034]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 103) with member_id aiokafka-0.8.0-1121aa7a-6bbf-4e10-8e5d-fa1755b2679e
# [2034]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 103) with member_id aiokafka-0.8.0-f2af1956-cc48-4799-bedd-57d9451bd878
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 103) with member_id aiokafka-0.8.0-72f72e32-2e92-4506-8ec4-b20a2cb34a83
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 103) with member_id aiokafka-0.8.0-01cc591e-15d4-492a-bca5-5152b1c63af4
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {'training_data': 1} to {'training_data': 1, 'realitime_data': 1}.
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 103
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 103
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [2032]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2030]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 103
# [2030]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2030]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 103
# [2030]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2034]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 103
# [2034]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2034]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 103
# [2034]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2028]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 103
# [2028]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [2028]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 103
# [2028]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# Starting process cleanup, this may take a few seconds...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 2028...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 2030...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 2032...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 2034...
# [2032]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [2030]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [2030]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [2030]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [2034]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [2034]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [2034]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [2032]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [2032]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [2028]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [2028]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [2028]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] __main__: terminate_asyncio_process(): Process 2030 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 2028 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 2032 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 2034 terminated.
# ok
