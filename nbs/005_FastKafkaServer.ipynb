# %%
# | default_exp server

# %%
# | export

import importlib
import sys
import asyncio
from typing import *
from contextlib import contextmanager
from pathlib import Path
import threading
import signal
from contextlib import ExitStack, contextmanager
from tempfile import TemporaryDirectory


import multiprocessing
from fastcore.meta import delegates
from fastcore.basics import patch
import typer
import asyncer

from fastkafka.application import FastKafka
from fastkafka.testing import change_dir
from fastkafka._components.helpers import _import_from_string, generate_app_src
from fastkafka._components.logger import get_logger

# %%
import os
from time import sleep
from pydantic import BaseModel
from fastkafka._components.logger import supress_timestamps

# %%
# | notest

# allows async calls in notebooks

import nest_asyncio

# %%
# | notest

nest_asyncio.apply()

# %%
# | export

logger = get_logger(__name__)

# %%
supress_timestamps()
logger = get_logger(__name__, level=20)
logger.info("ok")
# Out:
# [INFO] __main__: ok

# %%
def create_test_app():
    app = FastKafka(bootstrap_servers="tvrtko-fastkafka-kafka-1:9092")

    class MyMessage(BaseModel):
        msg: str

    @app.consumes()
    def on_my_topic(msg: MyMessage):
        pass

    return app

# %%
# | export


@contextmanager
def generate_app_in_tmp() -> Generator[str, None, None]:
    with TemporaryDirectory() as d:
        src_path = Path(d) / "main.py"
        generate_app_src(src_path)
        with change_dir(d):
            import_str = f"{src_path.stem}:kafka_app"
            yield import_str

# %%
# | export


class ServerProcess:
    def __init__(self, app: str):
        self.app = app
        self.should_exit = False

    def run(self) -> None:
        return asyncio.run(self._serve())

    async def _serve(self) -> None:
        self._install_signal_handlers()

        self.application = _import_from_string(self.app)

        async with self.application:
            await self._main_loop()

    def _install_signal_handlers(self) -> None:
        if threading.current_thread() is not threading.main_thread():
            raise RuntimeError()

        loop = asyncio.get_event_loop()

        HANDLED_SIGNALS = (
            signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
            signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
        )

        def handle_exit(sig: int) -> None:
            self.should_exit = True

        for sig in HANDLED_SIGNALS:
            loop.add_signal_handler(sig, handle_exit, sig)

    async def _main_loop(self) -> None:
        while not self.should_exit:
            await asyncio.sleep(0.1)

# %%
# | export

_app = typer.Typer()


@_app.command()
def run_fastkafka_server_process(
    app: str = typer.Argument(
        ...,
        help="input in the form of 'path:app', where **path** is the path to a python file and **app** is an object of type **FastKafka**.",
    )
) -> None:
    ServerProcess(app).run()

# %%
# | notest

print("WARNING: make sure you save the notebook before running this cell\n")

print("Exporting and installing the new version of the CLI command...")
await asyncio.create_subprocess_exec("nbdev_export")
export_process = await asyncio.create_subprocess_exec("nbdev_export")
await export_process.wait()
assert export_process.returncode == 0

install_process = await asyncio.create_subprocess_exec(
    "pip", "install", "-e", "..[dev]"
)
await install_process.wait()
assert install_process.returncode == 0

print("ok")
# Out:
# WARNING: make sure you save the notebook before running this cell
#
# Exporting and installing the new version of the CLI command...
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///work/fastkafka
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: aiofiles>=22.1.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (22.1.0)
# Requirement already satisfied: aiokafka>=0.8.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (0.8.0)
# Requirement already satisfied: asyncer>=0.0.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (0.0.2)
# Requirement already satisfied: confluent-kafka>=1.9.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (2.0.2)
# Requirement already satisfied: docstring-parser>=0.15 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (0.15)
# Requirement already satisfied: fastapi>=0.85.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (0.89.1)
# Requirement already satisfied: fastcore>=1.5.27 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.0rc0) (1.5.27)
# Requirement already satisfied: httpx>=0.23.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (0.23.3)
# Requirement already satisfied: ipywidgets>=8.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (8.0.4)
# Requirement already satisfied: python-multipart>=0.0.5 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (0.0.5)
# Requirement already satisfied: requests>=2.28.1 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.0rc0) (2.28.2)
# Requirement already satisfied: tqdm>=4.62 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.0rc0) (4.64.1)
# Requirement already satisfied: bandit>=1.7.4 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (1.7.4)
# Requirement already satisfied: black>=22.10.0 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.0rc0) (22.12.0)
# Requirement already satisfied: email-validator>=1.3.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (1.3.1)
# Requirement already satisfied: isort>=5.11.4 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (5.12.0)
# Requirement already satisfied: mypy>=0.991 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (0.991)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.0rc0) (7.2.9)
# Requirement already satisfied: nbdev-mkdocs>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.0rc0) (1.0.0)
# Requirement already satisfied: nbqa>=1.6.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (1.6.1)
# Requirement already satisfied: nest-asyncio>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.0rc0) (1.5.6)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from fastkafka==0.1.0rc0) (1.24.1)
# Requirement already satisfied: pandas>=1.2.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (1.5.3)
# Requirement already satisfied: pre-commit>=2.21.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (3.0.3)
# Requirement already satisfied: pytest>=7.1.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (7.2.1)
# Requirement already satisfied: semgrep>=1.3.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (1.9.0)
# Requirement already satisfied: uvicorn>=0.20 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastkafka==0.1.0rc0) (0.20.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from aiokafka>=0.8.0->fastkafka==0.1.0rc0) (23.0)
# Requirement already satisfied: kafka-python>=2.0.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from aiokafka>=0.8.0->fastkafka==0.1.0rc0) (2.0.2)
# Requirement already satisfied: async-timeout in /usr/local/lib/python3.10/dist-packages (from aiokafka>=0.8.0->fastkafka==0.1.0rc0) (4.0.2)
# Requirement already satisfied: anyio<4.0.0,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from asyncer>=0.0.2->fastkafka==0.1.0rc0) (3.6.2)
# Requirement already satisfied: GitPython>=1.0.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from bandit>=1.7.4->fastkafka==0.1.0rc0) (3.1.30)
# Requirement already satisfied: stevedore>=1.20.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from bandit>=1.7.4->fastkafka==0.1.0rc0) (4.1.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from bandit>=1.7.4->fastkafka==0.1.0rc0) (6.0)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black>=22.10.0->fastkafka==0.1.0rc0) (2.6.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black>=22.10.0->fastkafka==0.1.0rc0) (8.1.3)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black>=22.10.0->fastkafka==0.1.0rc0) (2.0.1)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black>=22.10.0->fastkafka==0.1.0rc0) (0.11.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black>=22.10.0->fastkafka==0.1.0rc0) (0.4.3)
# Requirement already satisfied: dnspython>=1.15.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from email-validator>=1.3.0->fastkafka==0.1.0rc0) (2.3.0)
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email-validator>=1.3.0->fastkafka==0.1.0rc0) (3.4)
# Requirement already satisfied: starlette==0.22.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastapi>=0.85.1->fastkafka==0.1.0rc0) (0.22.0)
# Requirement already satisfied: pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2 in /home/tvrtko/.local/lib/python3.10/site-packages (from fastapi>=0.85.1->fastkafka==0.1.0rc0) (1.10.4)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from fastcore>=1.5.27->fastkafka==0.1.0rc0) (23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastkafka==0.1.0rc0) (2022.12.7)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/tvrtko/.local/lib/python3.10/site-packages (from httpx>=0.23.0->fastkafka==0.1.0rc0) (1.5.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from httpx>=0.23.0->fastkafka==0.1.0rc0) (0.16.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->fastkafka==0.1.0rc0) (1.3.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from ipywidgets>=8.0->fastkafka==0.1.0rc0) (3.0.5)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0->fastkafka==0.1.0rc0) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from ipywidgets>=8.0->fastkafka==0.1.0rc0) (4.0.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0->fastkafka==0.1.0rc0) (6.21.0)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0->fastkafka==0.1.0rc0) (8.9.0)
# Requirement already satisfied: typing-extensions>=3.10 in /usr/local/lib/python3.10/dist-packages (from mypy>=0.991->fastkafka==0.1.0rc0) (4.4.0)
# Requirement already satisfied: mkdocs>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (1.4.2)
# Requirement already satisfied: playwright>=1.28.0 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (1.30.0)
# Requirement already satisfied: nbdev>=2.3.9 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (2.3.9)
# Requirement already satisfied: mkdocs-literate-nav>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.6.0)
# Requirement already satisfied: openai>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.26.4)
# Requirement already satisfied: mkdocs-section-index>=0.3.4 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.3.5)
# Requirement already satisfied: ruamel.yaml>=0.17.21 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.17.21)
# Requirement already satisfied: docstring-gen>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.2.2)
# Requirement already satisfied: mkdocs-material>=8.5.11 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (9.0.9)
# Requirement already satisfied: mkdocstrings==0.18.1 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.18.1)
# Requirement already satisfied: configupdater>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (3.1.1)
# Requirement already satisfied: griffe>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.25.4)
# Requirement already satisfied: typer[all]>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.7.0)
# Requirement already satisfied: mkdocstrings-python-legacy>=0.2 in /usr/local/lib/python3.10/dist-packages (from mkdocstrings==0.18.1->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.2.2)
# Requirement already satisfied: MarkupSafe>=1.1 in /usr/local/lib/python3.10/dist-packages (from mkdocstrings==0.18.1->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (2.1.2)
# Requirement already satisfied: Markdown>=3.3 in /usr/local/lib/python3.10/dist-packages (from mkdocstrings==0.18.1->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (3.3.7)
# Requirement already satisfied: mkdocs-autorefs>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from mkdocstrings==0.18.1->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.4.1)
# Requirement already satisfied: pymdown-extensions>=6.3 in /usr/local/lib/python3.10/dist-packages (from mkdocstrings==0.18.1->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (9.9.2)
# Requirement already satisfied: Jinja2>=2.11.1 in /usr/local/lib/python3.10/dist-packages (from mkdocstrings==0.18.1->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (3.1.2)
# Requirement already satisfied: tokenize-rt>=3.2.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from nbqa>=1.6.0->fastkafka==0.1.0rc0) (5.0.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->fastkafka==0.1.0rc0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from pandas>=1.2.0->fastkafka==0.1.0rc0) (2022.7.1)
# Requirement already satisfied: identify>=1.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from pre-commit>=2.21.0->fastkafka==0.1.0rc0) (2.5.17)
# Requirement already satisfied: cfgv>=2.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from pre-commit>=2.21.0->fastkafka==0.1.0rc0) (3.3.1)
# Requirement already satisfied: virtualenv>=20.10.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from pre-commit>=2.21.0->fastkafka==0.1.0rc0) (20.17.1)
# Requirement already satisfied: nodeenv>=0.11.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from pre-commit>=2.21.0->fastkafka==0.1.0rc0) (1.7.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/tvrtko/.local/lib/python3.10/site-packages (from pytest>=7.1.0->fastkafka==0.1.0rc0) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/tvrtko/.local/lib/python3.10/site-packages (from pytest>=7.1.0->fastkafka==0.1.0rc0) (1.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from pytest>=7.1.0->fastkafka==0.1.0rc0) (22.2.0)
# Requirement already satisfied: iniconfig in /home/tvrtko/.local/lib/python3.10/site-packages (from pytest>=7.1.0->fastkafka==0.1.0rc0) (2.0.0)
# Requirement already satisfied: six>=1.4.0 in /usr/lib/python3/dist-packages (from python-multipart>=0.0.5->fastkafka==0.1.0rc0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->fastkafka==0.1.0rc0) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28.1->fastkafka==0.1.0rc0) (1.26.14)
# Requirement already satisfied: colorama~=0.4.0 in /usr/local/lib/python3.10/dist-packages (from semgrep>=1.3.0->fastkafka==0.1.0rc0) (0.4.6)
# Requirement already satisfied: parsy~=2.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep>=1.3.0->fastkafka==0.1.0rc0) (2.0)
# Requirement already satisfied: python-lsp-jsonrpc~=1.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep>=1.3.0->fastkafka==0.1.0rc0) (1.0.0)
# Requirement already satisfied: jsonschema~=4.6 in /usr/local/lib/python3.10/dist-packages (from semgrep>=1.3.0->fastkafka==0.1.0rc0) (4.17.3)
# Requirement already satisfied: wcmatch~=8.3 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep>=1.3.0->fastkafka==0.1.0rc0) (8.4.1)
# Requirement already satisfied: peewee~=3.14 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep>=1.3.0->fastkafka==0.1.0rc0) (3.15.4)
# Requirement already satisfied: click-option-group~=0.5 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep>=1.3.0->fastkafka==0.1.0rc0) (0.5.5)
# Requirement already satisfied: defusedxml~=0.7.1 in /usr/local/lib/python3.10/dist-packages (from semgrep>=1.3.0->fastkafka==0.1.0rc0) (0.7.1)
# Requirement already satisfied: boltons~=21.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep>=1.3.0->fastkafka==0.1.0rc0) (21.0.0)
# Requirement already satisfied: glom~=22.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from semgrep>=1.3.0->fastkafka==0.1.0rc0) (22.1.0)
# Requirement already satisfied: h11>=0.8 in /home/tvrtko/.local/lib/python3.10/site-packages (from uvicorn>=0.20->fastkafka==0.1.0rc0) (0.14.0)
# Requirement already satisfied: nbformat>=5.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->fastkafka==0.1.0rc0) (5.7.3)
# Requirement already satisfied: mistune<3,>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from nbconvert->fastkafka==0.1.0rc0) (2.0.4)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->fastkafka==0.1.0rc0) (2.14.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->fastkafka==0.1.0rc0) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->fastkafka==0.1.0rc0) (0.7.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->fastkafka==0.1.0rc0) (4.11.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->fastkafka==0.1.0rc0) (0.2.2)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.10/dist-packages (from nbconvert->fastkafka==0.1.0rc0) (5.2.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->fastkafka==0.1.0rc0) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->fastkafka==0.1.0rc0) (1.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from GitPython>=1.0.1->bandit>=1.7.4->fastkafka==0.1.0rc0) (4.0.10)
# Requirement already satisfied: face>=20.1.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from glom~=22.1->semgrep>=1.3.0->fastkafka==0.1.0rc0) (22.0.0)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.0rc0) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.0rc0) (8.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.0rc0) (5.9.4)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.0rc0) (0.1.2)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.0rc0) (6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.0rc0) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=8.0->fastkafka==0.1.0rc0) (25.0.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (3.0.36)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (5.1.1)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (0.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema~=4.6->semgrep>=1.3.0->fastkafka==0.1.0rc0) (0.19.3)
# Requirement already satisfied: watchdog>=2.0 in /usr/local/lib/python3.10/dist-packages (from mkdocs>=1.4.2->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (2.2.1)
# Requirement already satisfied: ghp-import>=1.0 in /usr/local/lib/python3.10/dist-packages (from mkdocs>=1.4.2->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (2.1.0)
# Requirement already satisfied: pyyaml-env-tag>=0.1 in /usr/local/lib/python3.10/dist-packages (from mkdocs>=1.4.2->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.1)
# Requirement already satisfied: mergedeep>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from mkdocs>=1.4.2->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (1.3.4)
# Requirement already satisfied: regex>=2022.4.24 in /usr/local/lib/python3.10/dist-packages (from mkdocs-material>=8.5.11->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (2022.10.31)
# Requirement already satisfied: mkdocs-material-extensions>=1.1 in /usr/local/lib/python3.10/dist-packages (from mkdocs-material>=8.5.11->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (1.1.1)
# Requirement already satisfied: asttokens in /usr/local/lib/python3.10/dist-packages (from nbdev>=2.3.9->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (2.2.1)
# Requirement already satisfied: execnb>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from nbdev>=2.3.9->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.1.4)
# Requirement already satisfied: ghapi>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from nbdev>=2.3.9->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (1.0.3)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.10/dist-packages (from nbdev>=2.3.9->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (1.6.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat>=5.1->nbconvert->fastkafka==0.1.0rc0) (2.16.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nodeenv>=0.11.1->pre-commit>=2.21.0->fastkafka==0.1.0rc0) (59.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai>=0.25.0->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (3.8.3)
# Requirement already satisfied: greenlet==2.0.1 in /usr/local/lib/python3.10/dist-packages (from playwright>=1.28.0->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (2.0.1)
# Requirement already satisfied: pyee==9.0.4 in /usr/local/lib/python3.10/dist-packages (from playwright>=1.28.0->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (9.0.4)
# Requirement already satisfied: ujson>=3.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from python-lsp-jsonrpc~=1.0.0->semgrep>=1.3.0->fastkafka==0.1.0rc0) (5.7.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml>=0.17.21->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.2.7)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/tvrtko/.local/lib/python3.10/site-packages (from stevedore>=1.20.0->bandit>=1.7.4->fastkafka==0.1.0rc0) (5.11.1)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]>=0.7.0->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (1.5.0.post1)
# Requirement already satisfied: rich<13.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]>=0.7.0->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (12.6.0)
# Requirement already satisfied: filelock<4,>=3.4.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit>=2.21.0->fastkafka==0.1.0rc0) (3.9.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in /home/tvrtko/.local/lib/python3.10/site-packages (from virtualenv>=20.10.0->pre-commit>=2.21.0->fastkafka==0.1.0rc0) (0.3.6)
# Requirement already satisfied: bracex>=2.1.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from wcmatch~=8.3->semgrep>=1.3.0->fastkafka==0.1.0rc0) (2.3.post1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->fastkafka==0.1.0rc0) (2.3.2.post1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->fastkafka==0.1.0rc0) (0.5.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/tvrtko/.local/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.1->bandit>=1.7.4->fastkafka==0.1.0rc0) (5.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (0.8.3)
# Requirement already satisfied: pytkdocs>=0.14 in /usr/local/lib/python3.10/dist-packages (from mkdocstrings-python-legacy>=0.2->mkdocstrings==0.18.1->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.16.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (0.2.6)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from rich<13.0.0,>=10.11.0->typer[all]>=0.7.0->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.9.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai>=0.25.0->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai>=0.25.0->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai>=0.25.0->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai>=0.25.0->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (6.0.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse->nbdev>=2.3.9->nbdev-mkdocs>=0.0.4->fastkafka==0.1.0rc0) (0.37.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.0->fastkafka==0.1.0rc0) (1.2.0)
# Installing collected packages: fastkafka
#   Attempting uninstall: fastkafka
#     Found existing installation: fastkafka 0.1.0rc0
#     Uninstalling fastkafka-0.1.0rc0:
#       Successfully uninstalled fastkafka-0.1.0rc0
#   Running setup.py develop for fastkafka
# Successfully installed fastkafka
# ok

# %%
# | export


async def terminate_asyncio_process(p: asyncio.subprocess.Process) -> None:
    logger.info(f"terminate_asyncio_process(): Terminating the process {p.pid}...")
    # Check if SIGINT already propagated to process
    try:
        await asyncio.wait_for(p.wait(), 1)
        logger.info(
            f"terminate_asyncio_process(): Process {p.pid} was already terminated."
        )
        return
    except asyncio.TimeoutError:
        pass

    for i in range(3):
        p.terminate()
        try:
            await asyncio.wait_for(p.wait(), 10)
            logger.info(f"terminate_asyncio_process(): Process {p.pid} terminated.")
            return
        except asyncio.TimeoutError:
            logger.warning(
                f"terminate_asyncio_process(): Process {p.pid} not terminated, retrying..."
            )

    logger.warning(f"Killing the process {p.pid}...")
    p.kill()
    await p.wait()
    logger.warning(f"terminate_asyncio_process(): Process {p.pid} killed!")

# %%
with generate_app_in_tmp() as app:
    proc = await asyncio.create_subprocess_exec(
        "run_fastkafka_server_process", app, stdout=asyncio.subprocess.PIPE
    )
    sleep(5)
    await terminate_asyncio_process(proc)
    outputs, _ = await proc.communicate()

    print(outputs.decode("utf-8"))
    assert proc.returncode == 0
# Out:
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 3384...
# [INFO] __main__: terminate_asyncio_process(): Process 3384 terminated.
# [INFO] main: check
# [INFO] fastkafka._components.asyncapi: Old async specifications at '/tmp/tmpplvthtrc/asyncapi/spec/asyncapi.yml' does not exist.
# [INFO] fastkafka._components.asyncapi: New async specifications generated at: '/tmp/tmpplvthtrc/asyncapi/spec/asyncapi.yml'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1003 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 79) with member_id aiokafka-0.8.0-98a2c066-99ab-4353-b24a-ff05c7c2e11d
# [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1003 for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 79
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group tvrtko-fastkafka-kafka-1:9092_group because it is rebalancing
# [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='realitime_data', partition=0)}) for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 80) with member_id aiokafka-0.8.0-98a2c066-99ab-4353-b24a-ff05c7c2e11d
# [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 80) with member_id aiokafka-0.8.0-758e0918-6646-447b-8b1f-38a9071e695a
# [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {'realitime_data': 1} to {'realitime_data': 1, 'training_data': 1}.
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 80
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 80
# [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.

# %%
# | export


async def run_fastkafka_server(num_workers: int, app: str) -> None:
    loop = asyncio.get_event_loop()

    HANDLED_SIGNALS = (
        signal.SIGINT,  # Unix signal 2. Sent by Ctrl+C.
        signal.SIGTERM,  # Unix signal 15. Sent by `kill <pid>`.
    )

    d = {"should_exit": False}

    def handle_exit(sig: int, d: Dict[str, bool] = d) -> None:
        d["should_exit"] = True

    for sig in HANDLED_SIGNALS:
        loop.add_signal_handler(sig, handle_exit, sig)

    async with asyncer.create_task_group() as tg:
        tasks = [
            tg.soonify(asyncio.create_subprocess_exec)(
                "run_fastkafka_server_process",
                app,
                stdout=asyncio.subprocess.PIPE,
                stdin=asyncio.subprocess.PIPE,
            )
            for i in range(num_workers)
        ]

    procs = [task.value for task in tasks]

    async def log_output(
        output: Optional[asyncio.StreamReader], pid: int, d: Dict[str, bool] = d
    ) -> None:
        if output is None:
            raise RuntimeError("Expected StreamReader, got None. Is stdout piped?")
        while not output.at_eof():
            outs = await output.readline()
            if outs != b"":
                typer.echo(f"[{pid:03d}]: " + outs.decode("utf-8"), nl=False)

    async with asyncer.create_task_group() as tg:
        for proc in procs:
            tg.soonify(log_output)(proc.stdout, proc.pid)

        while not d["should_exit"]:
            await asyncio.sleep(0.2)

        typer.echo("Starting process cleanup, this may take a few seconds...")
        for proc in procs:
            tg.soonify(terminate_asyncio_process)(proc)

    for proc in procs:
        output, _ = await proc.communicate()
        if output:
            typer.echo(f"[{proc.pid:03d}]: " + output.decode("utf-8"), nl=False)

    returncodes = [proc.returncode for proc in procs]
    if not returncodes == [0] * len(procs):
        typer.secho(
            f"Return codes are not all zero: {returncodes}",
            err=True,
            fg=typer.colors.RED,
        )
        raise typer.Exit(1)

# %%
# | export


@contextmanager
def run_in_process(
    target: Callable[..., Any]
) -> Generator[multiprocessing.Process, None, None]:
    p = multiprocessing.Process(target=target)
    try:
        p.start()
        yield p
    except Exception as e:
        print(f"Exception raised {e=}")
    finally:
        p.terminate()
        p.join()

# %%
with generate_app_in_tmp() as app:

    def run_fastkafka_server_test():
        asyncio.run(run_fastkafka_server(4, app))

    with run_in_process(run_fastkafka_server_test) as p:
        sleep(5)

    assert p.exitcode == 0
    p.close()

print("ok")
# Out:
# [3392]: [INFO] main: check
# [3390]: [INFO] main: check
# [3392]: [INFO] fastkafka._components.asyncapi: Old async specifications at '/tmp/tmpzd3bfz7q/asyncapi/spec/asyncapi.yml' does not exist.
# [3394]: [INFO] main: check
# [3390]: [INFO] fastkafka._components.asyncapi: Old async specifications at '/tmp/tmpzd3bfz7q/asyncapi/spec/asyncapi.yml' does not exist.
# [3394]: [INFO] fastkafka._components.asyncapi: Old async specifications at '/tmp/tmpzd3bfz7q/asyncapi/spec/asyncapi.yml' does not exist.
# [3392]: [INFO] fastkafka._components.asyncapi: New async specifications generated at: '/tmp/tmpzd3bfz7q/asyncapi/spec/asyncapi.yml'
# [3392]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3392]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3392]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3392]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [3392]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [3392]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [3392]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [3392]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1003 for group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1003 for group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 82) with member_id aiokafka-0.8.0-343fec45-ac13-4ee1-8683-4f9081b6c842
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [3394]: [INFO] fastkafka._components.asyncapi: Keeping the old async specifications at: '/tmp/tmpzd3bfz7q/asyncapi/spec/asyncapi.yml'
# [3394]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3394]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3390]: [INFO] fastkafka._components.asyncapi: Keeping the old async specifications at: '/tmp/tmpzd3bfz7q/asyncapi/spec/asyncapi.yml'
# [3390]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3392]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 83) with member_id aiokafka-0.8.0-33481f92-2f79-4cf6-8907-cdca19531a59
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 83) with member_id aiokafka-0.8.0-343fec45-ac13-4ee1-8683-4f9081b6c842
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Metadata for topic has changed from {'training_data': 1} to {'training_data': 1, 'realitime_data': 1}.
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 83
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 83
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [3390]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3396]: [INFO] main: check
# [3394]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3394]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [3394]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [3394]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [3394]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [3394]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [3394]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1003 for group tvrtko-fastkafka-kafka-1:9092_group
# [3394]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3394]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3394]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1003 for group tvrtko-fastkafka-kafka-1:9092_group
# [3394]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3394]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3390]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3390]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [3390]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [3390]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [3390]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [3390]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [3390]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1003 for group tvrtko-fastkafka-kafka-1:9092_group
# [3390]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3390]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3390]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1003 for group tvrtko-fastkafka-kafka-1:9092_group
# [3390]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3390]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3396]: [INFO] fastkafka._components.asyncapi: Keeping the old async specifications at: '/tmp/tmpzd3bfz7q/asyncapi/spec/asyncapi.yml'
# [3396]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3396]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3396]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3396]: [INFO] fastkafka.application: _create_producer() : created producer using the config: '{'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092'}'
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() starting...
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer created using the following parameters: {'bootstrap_servers': 'tvrtko-fastkafka-kafka-1:9092', 'group_id': 'tvrtko-fastkafka-kafka-1:9092_group', 'auto_offset_reset': 'earliest', 'max_poll_records': 100}
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [3396]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'realitime_data'})
# [3396]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'realitime_data'}
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer started.
# [3396]: [INFO] aiokafka.consumer.subscription_state: Updating subscribed topics to: frozenset({'training_data'})
# [3396]: [INFO] aiokafka.consumer.consumer: Subscribed to topic(s): {'training_data'}
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer subscribed.
# [3396]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1003 for group tvrtko-fastkafka-kafka-1:9092_group
# [3396]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3396]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3396]: [INFO] aiokafka.consumer.group_coordinator: Discovered coordinator 1003 for group tvrtko-fastkafka-kafka-1:9092_group
# [3396]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3396]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group tvrtko-fastkafka-kafka-1:9092_group because it is rebalancing
# [3392]: [WARNING] aiokafka.consumer.group_coordinator: Heartbeat failed for group tvrtko-fastkafka-kafka-1:9092_group because it is rebalancing
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='training_data', partition=0)}) for group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Revoking previously assigned partitions frozenset({TopicPartition(topic='realitime_data', partition=0)}) for group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: (Re-)joining group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 84) with member_id aiokafka-0.8.0-33481f92-2f79-4cf6-8907-cdca19531a59
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 84) with member_id aiokafka-0.8.0-343fec45-ac13-4ee1-8683-4f9081b6c842
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Elected group leader -- performing partition assignments using roundrobin
# [3394]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 84) with member_id aiokafka-0.8.0-4ef5b258-f781-4713-bbe7-400721724ad7
# [3394]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 84) with member_id aiokafka-0.8.0-fedfb727-61ca-4817-a1ff-ae171ac91614
# [3390]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 84) with member_id aiokafka-0.8.0-45a29065-8ddd-4178-b76d-721e7da42ded
# [3390]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 84) with member_id aiokafka-0.8.0-4c102c02-34e7-42cf-97bc-11d362bbcc52
# [3396]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 84) with member_id aiokafka-0.8.0-7375abb6-6206-48b4-9e3d-35fef6c17230
# [3396]: [INFO] aiokafka.consumer.group_coordinator: Joined group 'tvrtko-fastkafka-kafka-1:9092_group' (generation 84) with member_id aiokafka-0.8.0-2497db46-5e80-4ca8-8826-338fe6a9fa08
# [3396]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 84
# [3396]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3396]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 84
# [3396]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3390]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 84
# [3390]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3390]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 84
# [3390]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3394]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 84
# [3394]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3394]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 84
# [3394]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions set() for group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 84
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Successfully synced group tvrtko-fastkafka-kafka-1:9092_group with generation 84
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='realitime_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# [3392]: [INFO] aiokafka.consumer.group_coordinator: Setting newly assigned partitions {TopicPartition(topic='training_data', partition=0)} for group tvrtko-fastkafka-kafka-1:9092_group
# Starting process cleanup, this may take a few seconds...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 3390...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 3392...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 3394...
# [INFO] __main__: terminate_asyncio_process(): Terminating the process 3396...
# [3390]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [3390]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [3390]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [3396]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [3396]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [3396]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [3394]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [3394]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [3394]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [3392]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [3392]: [INFO] aiokafka.consumer.group_coordinator: LeaveGroup request succeeded
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop(): Consumer stopped.
# [3392]: [INFO] fastkafka._components.aiokafka_consumer_loop: aiokafka_consumer_loop() finished.
# [INFO] __main__: terminate_asyncio_process(): Process 3394 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 3390 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 3396 terminated.
# [INFO] __main__: terminate_asyncio_process(): Process 3392 terminated.
# ok
